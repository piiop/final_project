# %%
import os
import time
import json
from io import BytesIO
from tqdm import tqdm

import numpy as np
import pandas as pd
import requests
from dotenv import load_dotenv

from PIL import Image
from ratelimit import limits, sleep_and_retry
from requests.exceptions import RequestException
from urllib.parse import urljoin

# %% [markdown]
# Accessing the Art Institute of Chicago's data dump

# %%
# Path JSONL file 
file_path = 'allArtworks.jsonl'

# Read the JSONL file
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Create a pandas DataFrame
df = pd.DataFrame(data)

print(df.info())

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132769 entries, 0 to 132768
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     132769 non-null  int64
#  1   title                  132768 non-null  object
#  2   main_reference_number  132769 non-null  object
#  3   department_title       126212 non-null  object
#  4   artist_title           114074 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 5.1+ MB
# None
#    id                                              title  \
# 0   4                                     Priest and Boy
# 1   9                     Interior of St. Mark's, Venice
# 2  11                                      Self-Portrait
# 3  16                             The Fall of the Giants
# 4  19  View of Ponte Lugano on the Anio, from Views o...
#
#   main_reference_number      department_title                artist_title
# 0                1880.1   Prints and Drawings   Lawrence Carmichael Earle
# 1              1887.232  Arts of the Americas          David Dalhoff Neal
# 2              1887.234  Arts of the Americas              Walter Shirlaw
# 3              1887.249   Prints and Drawings               Salvator Rosa
# 4              1887.252   Prints and Drawings  Giovanni Battista Piranesi

# %%
df['department_title'].value_counts()
# Out:
# department_title
# Prints and Drawings                                  51217
# Photography and Media                                23783
# Arts of Asia                                         16375
# Textiles                                             11547
# Architecture and Design                               5913
# Applied Arts of Europe                                5507
# Arts of the Americas                                  4246
# Arts of the Ancient Mediterranean and Byzantium       2195
# Contemporary Art                                      1721
# Arts of Africa                                        1493
# Painting and Sculpture of Europe                      1382
# Modern Art                                             463
# AIC Archives                                           242
# Ryerson and Burnham Libraries Special Collections      124
# Modern and Contemporary Art                              4
# Name: count, dtype: int64

# %%
# Set the path to the directory containing JSON files
json_dir = r"C:\Users\16148\Downloads\artic-api-data\json\artworks"

# Initialize an empty list to store the data from each JSON file
data_list = []

# Iterate through all JSON files in the directory
for filename in tqdm(os.listdir(json_dir), desc="Loading files"):
    if filename.endswith(".json"):
        file_path = os.path.join(json_dir, filename)
        with open(file_path, 'r', encoding='utf-8') as file:
            try:
                # Load the JSON data
                json_data = json.load(file)
                # Append the data to our list
                data_list.append(json_data)
            except json.JSONDecodeError:
                print(f"Error decoding JSON in file: {filename}")

# Create a DataFrame from the list of JSON data
all_df = pd.DataFrame(data_list)

# Display the first few rows and basic information about the DataFrame
all_df.info()
# Out:
# Loading files: 100%|██████████| 132769/132769 [36:02<00:00, 61.41it/s]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132769 entries, 0 to 132768
# Data columns (total 99 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   id                             132769 non-null  int64
#  1   api_model                      132769 non-null  object
#  2   api_link                       132769 non-null  object
#  3   is_boosted                     132769 non-null  bool
#  4   title                          132768 non-null  object
#  5   alt_titles                     1800 non-null    object
#  6   thumbnail                      118916 non-null  object
#  7   main_reference_number          132769 non-null  object
#  8   has_not_been_viewed_much       132769 non-null  bool
#  9   boost_rank                     20 non-null      float64
#  10  date_start                     127671 non-null  float64
#  11  date_end                       127671 non-null  float64
#  12  date_display                   132383 non-null  object
#  13  date_qualifier_title           132769 non-null  object
#  14  date_qualifier_id              56778 non-null   float64
#  15  artist_display                 132681 non-null  object
#  16  place_of_origin                123270 non-null  object
#  17  description                    12973 non-null   object
#  18  short_description              640 non-null     object
#  19  dimensions                     127933 non-null  object
#  20  dimensions_detail              132767 non-null  object
#  21  medium_display                 131615 non-null  object
#  22  inscriptions                   12171 non-null   object
#  23  credit_line                    126282 non-null  object
#  24  catalogue_display              24998 non-null   object
#  25  publication_history            11532 non-null   object
#  26  exhibition_history             10937 non-null   object
#  27  provenance_text                15427 non-null   object
#  28  edition                        3581 non-null    object
#  29  publishing_verification_level  132768 non-null  object
#  30  internal_department_id         132767 non-null  float64
#  31  fiscal_year                    83595 non-null   float64
#  32  fiscal_year_deaccession        6465 non-null    float64
#  33  is_public_domain               132769 non-null  bool
#  34  is_zoomable                    132769 non-null  bool
#  35  max_zoom_window_size           132769 non-null  int64
#  36  copyright_notice               12734 non-null   object
#  37  has_multimedia_resources       132769 non-null  bool
#  38  has_educational_resources      132769 non-null  bool
#  39  has_advanced_imaging           132769 non-null  bool
#  40  colorfulness                   118916 non-null  float64
#  41  color                          116810 non-null  object
#  42  latitude                       422 non-null     float64
#  43  longitude                      422 non-null     float64
#  44  latlon                         422 non-null     object
#  45  is_on_view                     126302 non-null  object
#  46  on_loan_display                75 non-null      object
#  47  gallery_title                  3770 non-null    object
#  48  gallery_id                     3770 non-null    float64
#  49  nomisma_id                     0 non-null       object
#  50  artwork_type_title             130120 non-null  object
#  51  artwork_type_id                130120 non-null  float64
#  52  department_title               126212 non-null  object
#  53  department_id                  126212 non-null  object
#  54  artist_id                      114074 non-null  float64
#  55  artist_title                   114074 non-null  object
#  56  alt_artist_ids                 132769 non-null  object
#  57  artist_ids                     132769 non-null  object
#  58  artist_titles                  132769 non-null  object
#  59  category_ids                   132769 non-null  object
#  60  category_titles                132769 non-null  object
#  61  term_titles                    132769 non-null  object
#  62  style_id                       36301 non-null   object
#  63  style_title                    36301 non-null   object
#  64  alt_style_ids                  132769 non-null  object
#  65  style_ids                      132769 non-null  object
#  66  style_titles                   132769 non-null  object
#  67  classification_id              131252 non-null  object
#  68  classification_title           131252 non-null  object
#  69  alt_classification_ids         132769 non-null  object
#  70  classification_ids             132769 non-null  object
#  71  classification_titles          132769 non-null  object
#  72  subject_id                     23200 non-null   object
#  73  alt_subject_ids                132769 non-null  object
#  74  subject_ids                    132769 non-null  object
#  75  subject_titles                 132769 non-null  object
#  76  material_id                    92158 non-null   object
#  77  alt_material_ids               132769 non-null  object
#  78  material_ids                   132769 non-null  object
#  79  material_titles                132769 non-null  object
#  80  technique_id                   29247 non-null   object
#  81  alt_technique_ids              132769 non-null  object
#  82  technique_ids                  132769 non-null  object
#  83  technique_titles               132769 non-null  object
#  84  theme_titles                   132769 non-null  object
#  85  image_id                       118916 non-null  object
#  86  alt_image_ids                  132769 non-null  object
#  87  document_ids                   132769 non-null  object
#  88  sound_ids                      132769 non-null  object
#  89  video_ids                      132769 non-null  object
#  90  text_ids                       132769 non-null  object
#  91  section_ids                    132769 non-null  object
#  92  section_titles                 132769 non-null  object
#  93  site_ids                       132769 non-null  object
#  94  suggest_autocomplete_all       132768 non-null  object
#  95  source_updated_at              132769 non-null  object
#  96  updated_at                     132769 non-null  object
#  97  timestamp                      132769 non-null  object
#  98  suggest_autocomplete_boosted   423 non-null     object
# dtypes: bool(7), float64(13), int64(2), object(77)
# memory usage: 94.1+ MB

# %%
all_df['artwork_type_title'].value_counts()
# Out:
# artwork_type_title
# Print                      45468
# Photograph                 25346
# Drawing and Watercolor     14697
# Textile                     9825
# Painting                    3916
# Vessel                      3578
# Architectural Drawing       3435
# Book                        3243
# Coin                        2783
# Costume and Accessories     2518
# Glass                       2364
# Sculpture                   2314
# Ceramics                    2055
# Decorative Arts             1468
# Metalwork                   1292
# Graphic Design              1134
# Design                       771
# Arms                         637
# Furniture                    587
# Religious/Ritual Object      481
# Armor                        430
# Architectural fragment       286
# Archives (groupings)         210
# Mixed Media                  187
# Model                        176
# Coverings and Hangings       171
# non-art                      163
# Film, Video, New Media       163
# Mask                          82
# Miniature room                69
# Funerary Object               67
# Installation                  59
# Basketry                      46
# Time Based Media              40
# Miniature Painting            22
# Furnishings                   19
# Medals                        10
# Audio-Video                    2
# Equipment                      2
# Materials                      1
# Icon                           1
# Digital Arts                   1
# Prototypes                     1
# Name: count, dtype: int64

# %%
all_df['style_titles'].value_counts()
# Out:
# style_titles
# []                                                                                 95963
# [Japanese (culture or style)]                                                       7766
# [21st Century]                                                                      4391
# [19th century]                                                                      3997
# [20th Century]                                                                      3113
#                                                                                    ...
# [maninka, Arts of Africa, african Art, Northern Africa and the Sahel]                  1
# [hausa, Arts of Africa, african Art, Northern Africa and the Sahel]                    1
# [shona, Arts of Africa, african Art, Eastern and Southern Africa]                      1
# [gwembe tonga, Arts of Africa, african Art, tonga, Eastern and Southern Africa]        1
# [late period (egyptian), saite period, twenty-sixth dynasty]                           1
# Name: count, Length: 2074, dtype: int64

# %%
# Combine single style_title and multiple style_titles
all_styles = []

# Add styles from style_title column (single style per artwork)
all_styles.extend(all_df['style_title'].dropna().unique())

# Add styles from style_titles column (multiple styles per artwork)
all_styles.extend([style for sublist in all_df['style_titles'] if sublist for style in sublist if style])

# Remove duplicates while preserving order
unique_styles = list(dict.fromkeys(all_styles))

print(f"Total number of unique styles: {len(unique_styles)}")
# Out:
# Total number of unique styles: 878

# %%
from collections import Counter

# Count occurrences of each style
style_counts = Counter(all_styles)

# Sort the styles by count in descending order
sorted_styles = sorted(style_counts.items(), key=lambda x: x[1], reverse=True)

print("Unique styles for Prints and Paintings, sorted by count:")
for style, count in sorted_styles:
    print(f"{style}: {count}")

print(f"\nTotal number of unique styles for Prints and Paintings: {len(sorted_styles)}")
# Out:
# Unique styles for Prints and Paintings, sorted by count:
# Japanese (culture or style): 7867
# 21st Century: 4864
# 19th century: 4836
# 20th Century: 3955
# Chinese (culture or style): 2291
# Modernism: 1737
# Arts of the Americas: 1498
# americas: 1332
# Pre-Columbian: 1181
# andes: 1150
# andean: 1146
# egyptian: 901
# roman period (egyptian): 851
# greco-roman (egyptian): 845
# asian: 782
# East Asian: 670
# ancient: 665
# Pop Art: 614
# Arts of Africa: 588
# early intermediate period: 560
# south american: 494
# african Art: 486
# Japanism: 467
# nineteenth century: 443
# contemporary: 428
# nazca: 420
# european: 402
# Cubism: 392
# avant-garde: 389
# moche: 365
# Pictorialism: 356
# Arts and Crafts Movement: 347
# bauhaus: 331
# qing: 329
# Coastal West Africa: 311
# South Asian: 285
# new kingdom: 271
# mesoamerican: 271
# 18th Century: 264
# chinese export: 233
# Himalayan: 228
# Impressionism: 227
# edo (japanese period): 225
# mochica: 221
# 17th Century: 217
# Folk Art: 215
# late intermediate period: 215
# Art Deco: 213
# third intermediate period: 213
# native american: 202
# medieval: 200
# african: 194
# meiji: 192
# Photo League: 183
# syrian: 179
# british: 176
# late period (egyptian): 171
# Realism: 169
# Pictures Generation: 168
# Surrealism: 159
# New Bauhaus (Institute of Design): 155
# American Arts and Crafts Movement: 150
# Islamic (culture or style): 147
# late edo: 145
# 16th Century: 141
# eighteenth dynasty: 139
# showa: 137
# chimú: 134
# studio pottery: 130
# imperial (roman): 127
# indonesian: 126
# inca: 124
# Korean (culture or style): 122
# Southeast Asian: 119
# British Arts and Crafts Movement: 119
# ming: 114
# asante: 111
# Renaissance: 108
# taisho: 108
# Post-Impressionism: 105
# 15th century: 95
# native north american: 95
# Northern Africa and the Sahel: 91
# Art Nouveau: 89
# southwest: 83
# chancay: 82
# ptolemaic: 81
# sixteenth century: 75
# Central Africa: 75
# yoruba: 74
# byzantine: 72
# akan: 71
# jouy-en-Josas: 71
# middle kingdom: 70
# Rococo: 65
# roman (ancient, style or period): 63
# antonine: 62
# Eastern and Southern Africa: 61
# postmodern: 61
# Conceptual Art: 60
# pueblo: 57
# colima: 55
# nineteenth dynasty: 54
# empire: 52
# maya: 52
# middle horizon: 52
# peruvian: 50
# second intermediate period: 50
# Neoclassicism: 49
# twenty-sixth dynasty: 49
# mochica v: 47
# coptic (period): 45
# mayan: 45
# isfahan: 44
# tiahuanaco: 44
# Constructivism: 43
# heisei: 43
# Indian (South Asian): 42
# red-figure: 41
# kuba (democratic republic of congo style: 40
# lambayeque: 40
# navajo: 39
# gur: 39
# Aesthetic Movement: 39
# lower central america: 38
# tudor: 38
# greek: 36
# huari: 36
# republic period: 36
# stuart: 36
# parthian: 35
# paracas: 35
# ica: 35
# Baroque: 34
# Classical: 34
# classic: 34
# fatimid: 34
# attic: 33
# indigenous: 33
# north american: 33
# chinoiserie: 32
# nayarit: 32
# saite period: 32
# twentieth dynasty: 32
# japonism: 31
# ramesside period: 31
# spanish colonial: 30
# bamana: 30
# twelfth dynasty: 30
# Magnum: 30
# talavera: 29
# elizabethan: 29
# english: 29
# west mexico: 29
# Prairie School: 28
# queen anne: 28
# Aestheticism: 28
# late classic: 28
# georgian: 27
# early horizon: 27
# canelos quichua: 26
# "bizarre" style: 25
# quechua: 25
# oceanic: 25
# melanesian: 24
# plains indian: 24
# mande: 24
# aymará: 23
# mamluk: 23
# hellenistic: 22
# jalisco: 22
# palestinian: 22
# senufo: 21
# teotihuacán: 21
# old kingdom: 21
# gothic revival: 21
# south african: 21
# chupicuaro: 20
# dogon: 20
# archaic (greek): 20
# twenty-first dynasty: 20
# mughal: 20
# louis xvi: 20
# modern movement: 20
# brazil: 20
# Barbizon School: 20
# anasazi: 20
# wiener werkstätte: 20
# fifteenth dynasty: 20
# black-figure: 20
# baule: 19
# greco-roman: 19
# classic veracruz: 19
# qianlong: 19
# gandharan: 19
# first intermediate period: 18
# zulu: 18
# Chuquibamba: 17
# igbo: 17
# kangxi: 17
# manchu-style: 17
# hyksos: 17
# ancestral pueblo (anasazi): 16
# louis xv: 16
# 14th century: 16
# lobi: 16
# Abstract: 16
# Mannerism: 16
# new guinea: 16
# american colonial: 16
# dine: 16
# mochica iii: 16
# nupe: 15
# kashan: 15
# design reform: 15
# Islamic: 14
# high classical: 14
# aztec: 14
# twenty-fifth dynasty: 14
# amish: 14
# bourrah: 14
# acoma: 14
# turkish: 14
# northern california: 14
# san ildefonso: 13
# Gothic (medieval): 13
# first dynasty: 13
# angkorean: 13
# directoire: 13
# dan: 13
# ayyubid: 13
# shipibo: 13
# Modern Latin American Art: 13
# vietnamese: 13
# mokoko: 13
# hispano-moresque: 12
# olmec: 12
# preclassic: 12
# orientalizing: 12
# Abstract Expressionism: 12
# thirtieth dynasty: 12
# egyptian revival: 12
# napoleonic: 12
# romantic: 12
# Surrealism in exile: 12
# early dynastic (egyptian): 12
# cambodian: 12
# central asian: 12
# regency: 11
# hopi: 11
# tlatilco: 11
# veracruz: 11
# caucasian: 11
# latin american: 11
# pennsylvania german: 11
# kente: 11
# kuba kingdom: 10
# predynastic: 10
# colonial inca: 10
# south italian: 10
# coclé: 10
# archaic america: 10
# Dada: 10
# veraguas: 10
# annamese: 10
# cibola: 10
# persian: 10
# arabian: 10
# papua new guinea: 10
# pachacamac: 10
# midwestern: 10
# victorian: 9
# chokwe: 9
# pomo: 9
# huastec: 9
# laotian: 9
# bamileke: 9
# edo (african): 9
# ewe: 9
# casas grandes: 9
# rococo revival: 9
# kongo: 9
# fon: 8
# france: 8
# songye: 8
# yaka: 8
# kota: 8
# four mile polychrome: 8
# American Fancy: 8
# mogollon: 8
# dutch: 8
# tenth dynasty: 8
# twenty-second dynasty: 8
# nieveria: 8
# mochica iv: 8
# late classical: 7
# zuñi: 7
# baga: 7
# mezcala: 7
# mossi: 7
# democratic republic of the congo: 7
# lega: 7
# cheyenne: 7
# ding: 7
# amarna period: 7
# nicoya: 7
# people's republic: 7
# bwa: 7
# chavín horizon: 7
# sioux: 7
# fostat: 7
# ida ou Nadif: 7
# Minimalism: 7
# mimbres: 7
# Gutai group: 7
# FSA/Depression: 7
# tewa: 7
# Symbolism: 7
# louis xiv: 7
# sepik: 7
# safavid: 7
# twenty-ninth dynasty: 7
# twenty-seventh dynasty: 7
# Star work: 7
# apulian: 6
# ottoman: 6
# rayy: 6
# classicism: 6
# mixtec: 6
# totonac: 6
# tairona: 6
# baatonu: 6
# cupisnique: 6
# middle edo: 6
# nuna: 6
# 13th century: 6
# swahili: 6
# kurumba: 6
# chippendale: 6
# tlingit: 6
# Tansaekhwa: 6
# han (chinese): 6
# guro: 6
# Abstraction: 6
# yazd: 6
# vanuatu: 6
# jacobean: 6
# blackware: 6
# twenty-eighth dynasty: 6
# lagoons peoples: 6
# ameca-zacoalco: 6
# thirteenth dynasty: 6
# california coast: 6
# moroccan: 6
# amol: 5
# sultanabad: 5
# ibibio: 5
# yurok: 5
# white-ground: 5
# cholula: 5
# musica: 5
# michoacan: 5
# lakota: 5
# pende: 5
# nguni: 5
# hadrianic: 5
# sheraton: 5
# tang: 5
# yüan: 5
# chosen: 5
# ijo: 5
# bukhara: 5
# cochiti: 5
# mississippian: 5
# lozi: 5
# kenyan: 5
# luba: 5
# fang: 5
# tekna: 5
# mid-century modern: 5
# eskimo: 5
# germanic: 5
# geometric: 5
# ocucaje: 5
# mali kingdom: 5
# corinthian (pottery style): 5
# paracas necropolis: 5
# abbasid: 5
# Jaina: 5
# fifth dynasty: 5
# eye-dazzler: 5
# cameroon grassfields: 5
# kashmiri: 5
# bariba: 5
# east african: 5
# javanese: 5
# chola: 5
# Dansaekhwa: 5
# mochica i: 5
# early etruscan: 4
# adam style: 4
# secession movement: 4
# biedermeier: 4
# minianka: 4
# Color Field: 4
# hohokam: 4
# de Stijl: 4
# cham (vietnamese): 4
# comanche: 4
# arapaho: 4
# punuk: 4
# yokuts: 4
# queen anne style: 4
# maidu: 4
# kwahu: 4
# maprik: 4
# tajin: 4
# ainu: 4
# mangbetu: 4
# hemba: 4
# bobo: 4
# liao: 4
# etruscan: 4
# makonde: 4
# santee: 4
# Pre-Raphaelite: 4
# early renaissance: 4
# nyoro: 4
# nsei: 4
# cham (bamileke): 4
# bamum: 4
# santo domingo: 4
# classical revival: 4
# zia: 4
# hehe: 4
# kazak: 4
# remojadas: 4
# hungarian: 4
# polish: 4
# rabat: 4
# ambrym: 4
# sassanian: 4
# holo: 4
# kubachi: 4
# pre-inca: 4
# peru: 4
# Flemish: 4
# late antique: 4
# hupa: 4
# oaxacan: 4
# twenty-fourth dynasty: 4
# twenty-third dynasty: 4
# colonial Peru: 4
# song: 4
# benin kingdom: 4
# outsider art: 4
# north coast: 4
# early christian: 4
# niger delta: 3
# constantinian: 3
# Nōpiloa: 3
# apache: 3
# russian: 3
# tellem: 3
# salinar: 3
# phoenician: 3
# nabis: 3
# panamint: 3
# fante: 3
# babessi: 3
# chinese chippendale: 3
# harlem renaissance: 3
# ngombe: 3
# cretan: 3
# kwazulu natal: 3
# wee: 3
# yombe: 3
# thembu: 3
# lulua: 3
# gurunsi: 3
# tutsi: 3
# mende: 3
# muromachi: 3
# gondar: 3
# zande: 3
# gnathian: 3
# hispaniola: 3
# ngbandi: 3
# nyamwezi: 3
# william and mary: 3
# somono: 3
# jerma: 3
# mambila: 3
# hausa: 3
# Bete: 3
# ethiopia: 3
# mfumte: 3
# trobriand island: 3
# nasrid: 3
# santa clara: 3
# frafra: 3
# trarza: 3
# dagestan: 3
# Hudson River School: 3
# gallinazo: 3
# fluxus: 3
# bhutanese: 3
# grunge: 3
# magic realist: 3
# late medieval: 3
# nonobjective: 3
# maasai: 3
# timor: 3
# hepplewhite: 3
# henri ii: 3
# bucchero: 3
# maori: 3
# late bronze age: 3
# new ireland: 3
# salado: 3
# trajanic: 3
# severan: 3
# aleut: 3
# Expressionism: 3
# louis xiii: 3
# greek revival: 3
# iznik: 3
# moorish: 3
# irian jaya: 3
# momoyama: 3
# hispano-islamic: 3
# Fauvism: 3
# lima: 3
# veramin: 3
# republican: 3
# jiajing: 3
# nalu: 3
# lagoon people: 3
# sixth dynasty: 3
# ixtlán del rio: 3
# iran: 3
# seventeenth dynasty: 3
# early classic: 3
# indigenous Art: 3
# sumatran: 3
# carribean: 3
# longuda: 3
# mwona: 3
# polynesian: 3
# saveh: 2
# sarouk: 2
# early cypriote: 2
# ojibwa: 2
# hellenistic etruscan: 2
# Rose Period: 2
# American craft: 2
# guacimo: 2
# puebla: 2
# crow: 2
# blackfoot: 2
# luluwa: 2
# Romanesque: 2
# late baroque: 2
# new britain: 2
# qajar: 2
# Calligram: 2
# southern song: 2
# georgian revival: 2
# ekonda: 2
# thirty-first dynasty: 2
# late hellenistic: 2
# sherbro: 2
# adiukru: 2
# late republican: 2
# tiv: 2
# merina: 2
# vili: 2
# potawatomi: 2
# sha: 2
# winnebago: 2
# turkoman: 2
# klikitat: 2
# fulani: 2
# paiute: 2
# new caledonian: 2
# lucanian: 2
# sui: 2
# oromo: 2
# penobscot: 2
# jen: 2
# mafa: 2
# gwari: 2
# teke: 2
# ambundu: 2
# kisi: 2
# gwembe tonga: 2
# shona: 2
# maninka: 2
# turka: 2
# yamba: 2
# ait bou addou: 2
# zela: 2
# lunda: 2
# wongo: 2
# kwere: 2
# Danube School: 2
# shoshone: 2
# bankoni: 2
# régence: 2
# cherokee: 2
# zigua: 2
# Baltimore silver: 2
# moors: 2
# gilded age: 2
# lumbo: 2
# proto-elamite: 2
# suprematist: 2
# synthetist: 2
# ndengese: 2
# tuareg: 2
# vienna: 2
# salampasu: 2
# yavapai: 2
# dakota: 2
# nyakyusa: 2
# chewa: 2
# chimú capac: 2
# reclining: 2
# koro: 2
# restoration (british): 2
# nabatean: 2
# diquis: 2
# soninke: 2
# Neogothique: 2
# carchi: 2
# nieuwe kunst: 2
# gördes: 2
# Op Art: 2
# neo-romantic: 2
# socialist realist: 2
# ejagham: 2
# early byzantine: 2
# postbellum: 2
# federal: 2
# Pointillism: 2
# Blue period: 2
# guapiles: 2
# norman: 2
# Return to Order: 2
# pahari: 2
# shamaye: 2
# qashqai: 2
# Rayonism: 2
# kantana: 2
# middle preclassic: 2
# solomon island: 2
# campanian: 2
# narino: 2
# manteño: 2
# Modern Art: 2
# shirvan: 2
# kirman: 2
# middle classic: 2
# bijogo: 2
# early cycladic: 2
# bijar: 2
# lengola: 2
# umayyad: 2
# kwakiutl: 2
# ushak: 2
# barocchetto: 2
# haida: 2
# nootka: 2
# muhammad mirza: 2
# mudéjar: 2
# waja: 2
# late assyrian: 2
# papago: 2
# luiseño: 2
# idoma: 2
# Orphism: 2
# tabriz: 2
# rhodian (iznik pottery style): 2
# guetar: 2
# louis philippe: 2
# Chicago Society of Etchers: 2
# khorasan: 2
# mbole: 2
# Russian Constructivism: 2
# chilkat: 2
# asmat: 2
# azapa: 2
# recuay: 2
# tiwanaku: 2
# guaraní: 2
# chicago imagist: 2
# heriz: 2
# karok: 2
# iron age: 2
# northern renaissance: 2
# Analytical Cubism: 2
# ketu: 2
# fourth dynasty: 2
# teton: 2
# rajasthani: 2
# rajput: 2
# genre painting: 2
# sixteenth dynasty: 2
# fourteenth dynasty: 2
# mongo: 2
# ngwana: 2
# drakensberg: 2
# Naturalism: 2
# angkor thom: 2
# suku: 2
# aja: 2
# mbunda: 2
# kasena: 2
# massim area: 2
# kiua: 2
# ameca: 2
# nez percé: 2
# nimiipuu: 2
# tikar: 2
# spatialism: 2
# Scandinavian Design: 2
# fin de siècle: 2
# cusco: 2
# cuzco: 2
# psychedelic: 2
# new zealand: 2
# bronze age: 2
# kushan: 2
# late preclassic: 2
# mochica ii: 2
# maranga: 2
# seljuk: 1
# Confetti Cubism: 1
# early iron age: 1
# mixteca-puebla: 1
# nara: 1
# warfare: 1
# ixtalan del rio: 1
# gerzean: 1
# studio furniture: 1
# protoclassic: 1
# izi: 1
# cayapó: 1
# gupta: 1
# Concrete poem: 1
# eighth dynasty: 1
# second dynasty: 1
# seventh dynasty: 1
# third dynasty: 1
# twifo hemang: 1
# twifo: 1
# ganga: 1
# eleventh dynasty: 1
# tibetan: 1
# koh ker: 1
# english (style, influenced): 1
# early imperial: 1
# jukun: 1
# araucanian: 1
# malagasy: 1
# baphuon: 1
# lagunillas: 1
# nsapo: 1
# deccani: 1
# haripunjaya: 1
# thai: 1
# kulere: 1
# nicaragua: 1
# san carlos: 1
# great lakes: 1
# majapahit: 1
# east javanese: 1
# first gondarine: 1
# heian: 1
# guangxu: 1
# volutes: 1
# javanese period (balinese): 1
# wayang: 1
# balinese: 1
# barambo: 1
# d'entrecasteaux: 1
# sidano: 1
# missouri: 1
# oribe: 1
# kalabari: 1
# bata: 1
# janjo: 1
# pare: 1
# tonga: 1
# ait mendes: 1
# segou: 1
# sorogo: 1
# marka: 1
# zhou: 1
# mindumu: 1
# obamba: 1
# kawakiutl: 1
# mbugu: 1
# bulunits: 1
# pukur: 1
# landuma: 1
# benin (ancient nigerian style): 1
# celtic: 1
# tabora: 1
# tanzania: 1
# punu: 1
# shira: 1
# mesopotamian: 1
# elamite: 1
# missippian: 1
# berber: 1
# kabyle: 1
# kasai: 1
# ngoombe: 1
# viennese: 1
# koro ache: 1
# international gothic: 1
# malinke: 1
# jula: 1
# dyula: 1
# female: 1
# microarchitecture: 1
# limoges: 1
# merovingian: 1
# northwest coast: 1
# chintz: 1
# fungom: 1
# genre: 1
# nasca: 1
# austrian: 1
# caribbean: 1
# synthetic cubist: 1
# jemez: 1
# Northeast coast: 1
# Ashcan School: 1
# mexican american: 1
# Chicago art center: 1
# taos: 1
# british colonial: 1
# nocturnal: 1
# ijebu: 1
# baroque revival: 1
# kangra: 1
# venado beach: 1
# panama: 1
# yongzheng: 1
# qingbai: 1
# sapi-portuguese: 1
# caroline: 1
# charles I period: 1
# plastic style: 1
# cycladic: 1
# spedos type: 1
# kushite: 1
# tarascan: 1
# akkoyunlu: 1
# assyrian: 1
# western jin: 1
# celtic (medieval): 1
# american scene: 1
# koryŏ: 1
# qijia: 1
# gansu: 1
# yangshao: 1
# jahangir: 1
# chincha: 1
# conibo: 1
# caddo: 1
# northern song: 1
# Regionalism: 1
# roosevelt: 1
# tonto: 1
# mewar: 1
#
# Total number of unique styles for Prints and Paintings: 878

# %%
# Create list of styles to use:

top_styles = [
    "Modernism",
    "Pop Art",
    "contemporary",
    "Cubism",
    "avant-garde",
    "bauhaus",
    "Impressionism",
    "Art Deco",
    "Folk Art",
    "meiji",
    "Realism",
    "Surrealism",
    "Renaissance",
    "Post-Impressionism",
    "Art Nouveau",
    "Rococo",
    "postmodern",
    "Conceptual Art",
    "Baroque",
    





]

# %%
def get_all_style_titles():
    base_url = "https://api.artic.edu/api/v1/category-terms"
    all_titles = []
    page = 1
    limit = 100  # Maximum allowed by the API

    while True:
        params = {
            "fields": "id,title",
            "limit": limit,
            "page": page,
            "query[term][category]": "Style",
            "sort": "title"
        }
        
        response = requests.get(base_url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            new_titles = [item['title'] for item in data['data']]
            all_titles.extend(new_titles)
            
            # Check if we've reached the last page
            if len(new_titles) < limit:
                break
            
            page += 1
        else:
            print(f"Error on page {page}: {response.status_code}")
            break

    return all_titles

# Fetch all style titles
style_titles = get_all_style_titles()

if style_titles:
    print(f"\nTotal styles retrieved: {len(style_titles)}")
else:
    print("Failed to retrieve style titles.")
# Out:
# Total styles retrieved: 10101

# %% [markdown]
# Match the style from the top_styles list to the style terms used by the API

# %%
def check_top_styles(style_titles, top_styles):
    # Convert all style_titles to lowercase for case-insensitive comparison
    style_titles_lower = [title.lower() for title in style_titles]
    
    # Check each top style
    not_found = []
    found = {}
    
    for style in top_styles:
        style_lower = style.lower()
        matches = []
        
        for i, title_lower in enumerate(style_titles_lower):
            if style_lower == title_lower:
                matches.append(style_titles[i])
            elif (style_lower == "art-deco" and "art deco" in title_lower) or \
                 (style_lower == "mannerism (late renaissance)" and ("mannerism" in title_lower or "late renaissance" in title_lower)) or \
                 (style_lower == "romanticism" and "romantic" in title_lower) or \
                 (style_lower == "art nouveau (modern)" and title_lower in ["modern art", "modern", "modernist", "modernism"]):
                matches.append(style_titles[i])
        
        if matches:
            found[style] = matches
        else:
            not_found.append(style)
    
    # Print results
    if not_found:
        print("The following styles were not found in the API results:")
        for style in not_found:
            print(f"- {style}")
    else:
        print("All top styles were found in the API results.")
    
    print("\nMatches found:")
    for style, matches in found.items():
        print(f"{style}:")
        for match in matches:
            print(f"  - {match}")
    
    # Print summary
    print(f"\nFound {len(found)} out of {len(top_styles)} top styles.")
    
    return found

# Usage
#found_styles = check_top_styles(style_titles, top_styles)

# %% [markdown]
# Create a list to use for search

# %%
# Convert found styles to style_search_terms list
style_search_terms = []
for matches in found_styles.values():
    style_search_terms.extend(matches)

# Remove duplicates while preserving order
style_search_terms = list(dict.fromkeys(style_search_terms))

print("Style search terms:")
for term in style_search_terms:
    print(f"- {term}")
print(f"\nTotal unique search terms: {len(style_search_terms)}")
# Out:
# Style search terms:
# - Impressionism
# - Realism
# - neo-romantic
# - romantic
# - Expressionism
# - Post-Impressionism
# - Baroque
# - modern art
# - modernism
# - Modern Art
# - modern
# - modernist
# - Modernism
# - surrealism
# - Surrealism
# - symbolism
# - Symbolism
# - Abstract Expressionism
# - Neoclassicism
# - Rococo
# - Cubism
# - northern renaissance
# - Pop art
# - Pop Art
# - mannerism
# - late renaissance
# - Mannerism
# - minimalism
# - Minimalism
# - Conceptual Art
# - Art Informel
# - early renaissance
# - ukiyo-e
# - Neo-Expressionism
# - high renaissance
# - lyrical abstraction
# - Fauvism
# - contemporary
# - Op Art
# - Art Deco
# - postmodern
#
# Total unique search terms: 41

# %% [markdown]
# Test our search terms by getting the first entry from each style

# %%
BASE_URL = "https://api.artic.edu/api/v1"

def get_artwork_by_style(style_term, limit=1):
    endpoint = f"{BASE_URL}/artworks/search"
    params = {
        "q": style_term,
        "fields": "id,title,style_title,image_id,artwork_type_title",
        "limit": limit
    }
    response = requests.get(endpoint, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('data', [])
    else:
        print(f"Error fetching data for {style_term}: {response.status_code}")
        return []

def create_test_dataframe(style_search_terms):
    all_artworks = []
    for term in style_search_terms:
        artworks = get_artwork_by_style(term)
        if artworks:
            artwork = artworks[0]
            artwork['search_term'] = term
            all_artworks.append(artwork)
    
    df = pd.DataFrame(all_artworks)
    if '_score' in df.columns:
        df = df.drop('_score', axis=1)
    return df

# Assuming style_search_terms is already defined
test_df = create_test_dataframe(style_search_terms)

print(f"Number of entries in test_df: {len(test_df)}")
# Out:
# Number of entries in test_df: 41

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artwork_type_title  41 non-null     object
#  1   style_title         32 non-null     object
#  2   id                  41 non-null     int64
#  3   image_id            41 non-null     object
#  4   title               41 non-null     object
#  5   search_term         41 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ KB

# %%
test_df
# Out:
#          artwork_type_title             style_title      id  \
# 0                  Painting           Impressionism   64729
# 1                  Painting             suprematist  207293
# 2                 Sculpture           late assyrian   64936
# 3               Mixed Media                    None   99775
# 4   Costume and Accessories           Expressionism   61859
# 5                 Sculpture      Post-Impressionism     719
# 6                 Sculpture                 Baroque   73413
# 7                  Painting                    None  109529
# 8                 Sculpture                    None  152961
# 9                  Painting                    None  109529
# 10                Sculpture                    None  152961
# 11     Archives (groupings)                    None  262292
# 12                Sculpture                    None  152961
# 13                 Painting              Surrealism   62323
# 14                 Painting              Surrealism   62323
# 15    Architectural Drawing            20th Century  131541
# 16    Architectural Drawing            20th Century  131541
# 17   Drawing and Watercolor  Abstract Expressionism   83889
# 18                Sculpture           Neoclassicism  160236
# 19                 Ceramics                  Rococo    5462
# 20                 Painting                  Cubism  109260
# 21                 Painting            15th century  110673
# 22                 Painting                 Pop Art  229363
# 23                 Painting                 Pop Art  229363
# 24                   Vessel          high classical   84551
# 25                  Textile             Renaissance   14690
# 26                   Vessel          high classical   84551
# 27                Sculpture              Minimalism  191371
# 28                Sculpture              Minimalism  191371
# 29                Sculpture          Conceptual Art  184105
# 30               Photograph                    None  191358
# 31  Costume and Accessories       Gothic (medieval)  229963
# 32                Sculpture            21st Century  189207
# 33                Sculpture           late assyrian   64936
# 34                  Textile             Renaissance   14690
# 35                 Painting              Surrealism   70374
# 36                 Painting               Modernism  201806
# 37                Sculpture                    None  152961
# 38                  Textile                  Op Art  261148
# 39           Miniature room                Art Deco   43732
# 40                    Model            20th Century  198976
#
#                                 image_id  \
# 0   ef96e79b-f481-8114-0804-4bd39c101983
# 1   12baff03-af57-0410-df53-740c56575732
# 2   c78e7b95-0652-a2dd-05f6-f9b1d68ff24d
# 3   19e4effc-bcab-2b1e-29f1-8325877111f3
# 4   8ec2ad7b-c47d-d189-5646-6c5b960b875c
# 5   d0a72b06-f1ee-4464-d58c-5e39bc0534b3
# 6   d19683c2-2ef4-e586-7add-c1008b6a8fb2
# 7   567b2141-2556-c195-01fe-b47c6d1a63dc
# 8   9036870e-9ec4-19ab-3d73-3cbf79c1af8b
# 9   567b2141-2556-c195-01fe-b47c6d1a63dc
# 10  9036870e-9ec4-19ab-3d73-3cbf79c1af8b
# 11  342b2214-04d5-de63-b577-55a08a618960
# 12  9036870e-9ec4-19ab-3d73-3cbf79c1af8b
# 13  4212f149-f02a-9deb-3806-8bb2396a2d91
# 14  4212f149-f02a-9deb-3806-8bb2396a2d91
# 15  d4e7be13-f1d8-7880-1eaf-b3a8477d5b85
# 16  d4e7be13-f1d8-7880-1eaf-b3a8477d5b85
# 17  25d605a9-0bbe-1e67-23e5-7669181908ed
# 18  8aa44471-0c6e-1880-c642-53d57f47636e
# 19  24853b28-97c5-5146-4fde-969559b40618
# 20  43bc66e2-95b2-fb3c-b9b1-232835bfd027
# 21  66c1797f-b87e-8736-cdf6-c490bd34863b
# 22  249173c2-0013-4624-211c-3e8fcf335048
# 23  249173c2-0013-4624-211c-3e8fcf335048
# 24  10d782f2-d7e8-4f1d-9779-8302ca35e29e
# 25  b4ccdf0f-8b1b-2969-e447-5402cbe56985
# 26  10d782f2-d7e8-4f1d-9779-8302ca35e29e
# 27  41d9b65a-6649-28e6-19d9-c16ef27df8f1
# 28  41d9b65a-6649-28e6-19d9-c16ef27df8f1
# 29  423f7516-ecf5-7304-f68a-598e96eb822d
# 30  d141a769-24af-ff07-d792-183ae73ae765
# 31  434a94cb-272e-06a0-5b4f-ba00a49c636d
# 32  0a4d7fed-ab8d-4772-1b42-2888218e8ff8
# 33  c78e7b95-0652-a2dd-05f6-f9b1d68ff24d
# 34  b4ccdf0f-8b1b-2969-e447-5402cbe56985
# 35  e61642c8-9c14-617c-771f-8fb892b90a4f
# 36  411dd5f9-8633-9dab-d64c-a038c0aa92b5
# 37  9036870e-9ec4-19ab-3d73-3cbf79c1af8b
# 38  04ee7711-f871-433f-89c1-89b4261fffa9
# 39  40724c6b-da7a-056f-210b-8d9ddff252e7
# 40  934a57ff-b343-afae-935a-46be8f666293
#
#                                                 title             search_term
# 0                       Early Morning, Tarpon Springs           Impressionism
# 1   Painterly Realism of a Football Player—Color M...                 Realism
# 2          Relief Showing the Head of a Winged Genius            neo-romantic
# 3                       Homage to the Romantic Ballet                romantic
# 4                                               Scarf           Expressionism
# 5                   A Burgher of Calais (Jean d'Aire)      Post-Impressionism
# 6           Bust of a Youth (Saint John the Baptist?)                 Baroque
# 7                         Reminiscence of a Cathedral              modern art
# 8               "Untitled" (Portrait of Ross in L.A.)               modernism
# 9                         Reminiscence of a Cathedral              Modern Art
# 10              "Untitled" (Portrait of Ross in L.A.)                  modern
# 11                Ludwig Mies van der Rohe Collection               modernist
# 12              "Untitled" (Portrait of Ross in L.A.)               Modernism
# 13                                  Magnetic Mountain              surrealism
# 14                                  Magnetic Mountain              Surrealism
# 15  System of Architectural Ornament, Plate 16, Im...               symbolism
# 16  System of Architectural Ornament, Plate 16, Im...               Symbolism
# 17                                 Two Women's Torsos  Abstract Expressionism
# 18                                     Head of Medusa           Neoclassicism
# 19                             Goat and Bee Cream Jug                  Rococo
# 20                                    Man with a Pipe                  Cubism
# 21                  Mater Dolorosa (Sorrowing Virgin)    northern renaissance
# 22                  Artist's Studio "Foot Medication"                 Pop art
# 23                  Artist's Studio "Foot Medication"                 Pop Art
# 24                          Bell Krater (Mixing Bowl)               mannerism
# 25                                           Fragment        late renaissance
# 26                          Bell Krater (Mixing Bowl)               Mannerism
# 27                                           Untitled              minimalism
# 28                                           Untitled              Minimalism
# 29                            Set of eight sculptures          Conceptual Art
# 30  Nelson Algren Pauses after Another White Sox L...            Art Informel
# 31                                        Signet Ring       early renaissance
# 32                                             Hinoki                 ukiyo-e
# 33         Relief Showing the Head of a Winged Genius       Neo-Expressionism
# 34                                           Fragment        high renaissance
# 35  Untitled (Dream of Venus) formerly Visions of ...     lyrical abstraction
# 36                                  Landscape (recto)                 Fauvism
# 37              "Untitled" (Portrait of Ross in L.A.)            contemporary
# 38                                           Mandarin                  Op Art
# 39  E-15: English Drawing Room of the Modern Perio...                Art Deco
# 40      Camouflage House, Burr Ridge, Illinois, Model              postmodern

# %% [markdown]
# Notice mixed media types were pulled. Searching with the API for just paintings along with the style_terms was causing errors,
# so I decided to pull all and will filter the dataframe afterwards. We'll also fill the missing values with the 'search_term' after some checking.
#
# Now we search for every piece of artwork matching our style terms.

# %%
BASE_URL = "https://api.artic.edu/api/v1"
RATE_LIMIT = 60  # requests per minute
MAX_RECORDS = 10000  # maximum records we can fetch for a single search query
CHECKPOINT_FILE = 'search_checkpoint.json'

def load_checkpoint():
    try:
        with open(CHECKPOINT_FILE, 'r') as f:
            return json.load(f)
    except FileNotFoundError:
        return {}

def save_checkpoint(checkpoint):
    with open(CHECKPOINT_FILE, 'w') as f:
        json.dump(checkpoint, f)

def get_artworks_by_style(style_term, limit=100, start_page=1):
    all_artworks = []
    page = start_page
    total_pages = None

    while (total_pages is None or page <= total_pages) and len(all_artworks) < MAX_RECORDS:
        try:
            endpoint = f"{BASE_URL}/artworks/search"
            params = {
                "q": style_term,
                "fields": "id,title,style_title,image_id,artwork_type_title",
                "limit": limit,
                "page": page
            }
            response = requests.get(endpoint, params=params)
            response.raise_for_status()
            
            data = response.json()
            artworks = data.get('data', [])
            all_artworks.extend(artworks)
            
            if total_pages is None:
                total_pages = data.get('pagination', {}).get('total_pages', 1)
                print(f"Total pages for {style_term}: {total_pages}")
            
            print(f"Fetched page {page} of {total_pages} for {style_term}")
            page += 1
            
            # Throttle to respect rate limit
            time.sleep(60 / RATE_LIMIT)
        
        except RequestException as e:
            print(f"Error fetching data for {style_term} on page {page}: {e}")
            break  
        
        if len(all_artworks) >= MAX_RECORDS:
            print(f"Reached {MAX_RECORDS} record limit for {style_term}")
            break
    
    return all_artworks, page

def create_full_dataframe(style_search_terms):
    all_artworks = []
    checkpoint = load_checkpoint()

    for term in style_search_terms:
        start_page = checkpoint.get(term, {}).get('next_page', 1)
        total_retrieved = checkpoint.get(term, {}).get('total_retrieved', 0)
        
        print(f"Fetching artworks for {term} starting from page {start_page}")
        artworks, next_page = get_artworks_by_style(term, start_page=start_page)
        
        for artwork in artworks:
            artwork['search_term'] = term
        all_artworks.extend(artworks)
        
        total_retrieved += len(artworks)
        checkpoint[term] = {'next_page': next_page, 'total_retrieved': total_retrieved}
        save_checkpoint(checkpoint)
        
        print(f"Total artworks retrieved for {term}: {total_retrieved}")
        
        if total_retrieved >= MAX_RECORDS:
            print(f"Reached {MAX_RECORDS} record limit for {term}. You can resume later.")
    
    df = pd.DataFrame(all_artworks)
    if '_score' in df.columns:
        df = df.drop('_score', axis=1)
    return df

# Usage
full_df = create_full_dataframe(style_search_terms)

print(f"Total number of artworks retrieved: {len(full_df)}")
# Out:
# Fetching artworks for Impressionism starting from page 1
# Total pages for Impressionism: 4
# Fetched page 1 of 4 for Impressionism
# Fetched page 2 of 4 for Impressionism
# Fetched page 3 of 4 for Impressionism
# Fetched page 4 of 4 for Impressionism
# Total artworks retrieved for Impressionism: 316
# Fetching artworks for Realism starting from page 1
# Total pages for Realism: 3
# Fetched page 1 of 3 for Realism
# Fetched page 2 of 3 for Realism
# Fetched page 3 of 3 for Realism
# Total artworks retrieved for Realism: 275
# Fetching artworks for neo-romantic starting from page 1
# Total pages for neo-romantic: 24
# Fetched page 1 of 24 for neo-romantic
# Fetched page 2 of 24 for neo-romantic
# Fetched page 3 of 24 for neo-romantic
# Fetched page 4 of 24 for neo-romantic
# Fetched page 5 of 24 for neo-romantic
# Fetched page 6 of 24 for neo-romantic
# Fetched page 7 of 24 for neo-romantic
# Fetched page 8 of 24 for neo-romantic
# Fetched page 9 of 24 for neo-romantic
# Fetched page 10 of 24 for neo-romantic
# Error fetching data for neo-romantic on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=neo-romantic&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for neo-romantic: 1000
# Fetching artworks for romantic starting from page 1
# Total pages for romantic: 24
# Fetched page 1 of 24 for romantic
# Fetched page 2 of 24 for romantic
# Fetched page 3 of 24 for romantic
# Fetched page 4 of 24 for romantic
# Fetched page 5 of 24 for romantic
# Fetched page 6 of 24 for romantic
# Fetched page 7 of 24 for romantic
# Fetched page 8 of 24 for romantic
# Fetched page 9 of 24 for romantic
# Fetched page 10 of 24 for romantic
# Error fetching data for romantic on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=romantic&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for romantic: 1000
# Fetching artworks for Expressionism starting from page 1
# Total pages for Expressionism: 1
# Fetched page 1 of 1 for Expressionism
# Total artworks retrieved for Expressionism: 12
# Fetching artworks for Post-Impressionism starting from page 1
# Total pages for Post-Impressionism: 5
# Fetched page 1 of 5 for Post-Impressionism
# Fetched page 2 of 5 for Post-Impressionism
# Fetched page 3 of 5 for Post-Impressionism
# Fetched page 4 of 5 for Post-Impressionism
# Fetched page 5 of 5 for Post-Impressionism
# Total artworks retrieved for Post-Impressionism: 455
# Fetching artworks for Baroque starting from page 1
# Total pages for Baroque: 3
# Fetched page 1 of 3 for Baroque
# Fetched page 2 of 3 for Baroque
# Fetched page 3 of 3 for Baroque
# Total artworks retrieved for Baroque: 213
# Fetching artworks for modern art starting from page 1
# Total pages for modern art: 433
# Fetched page 1 of 433 for modern art
# Fetched page 2 of 433 for modern art
# Fetched page 3 of 433 for modern art
# Fetched page 4 of 433 for modern art
# Fetched page 5 of 433 for modern art
# Fetched page 6 of 433 for modern art
# Fetched page 7 of 433 for modern art
# Fetched page 8 of 433 for modern art
# Fetched page 9 of 433 for modern art
# Fetched page 10 of 433 for modern art
# Error fetching data for modern art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=modern+art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for modern art: 1000
# Fetching artworks for modernism starting from page 1
# Total pages for modernism: 49
# Fetched page 1 of 49 for modernism
# Fetched page 2 of 49 for modernism
# Fetched page 3 of 49 for modernism
# Fetched page 4 of 49 for modernism
# Fetched page 5 of 49 for modernism
# Fetched page 6 of 49 for modernism
# Fetched page 7 of 49 for modernism
# Fetched page 8 of 49 for modernism
# Fetched page 9 of 49 for modernism
# Fetched page 10 of 49 for modernism
# Error fetching data for modernism on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=modernism&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for modernism: 1000
# Fetching artworks for Modern Art starting from page 1
# Total pages for Modern Art: 433
# Fetched page 1 of 433 for Modern Art
# Fetched page 2 of 433 for Modern Art
# Fetched page 3 of 433 for Modern Art
# Fetched page 4 of 433 for Modern Art
# Fetched page 5 of 433 for Modern Art
# Fetched page 6 of 433 for Modern Art
# Fetched page 7 of 433 for Modern Art
# Fetched page 8 of 433 for Modern Art
# Fetched page 9 of 433 for Modern Art
# Fetched page 10 of 433 for Modern Art
# Error fetching data for Modern Art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Modern+Art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Modern Art: 1000
# Fetching artworks for modern starting from page 1
# Total pages for modern: 49
# Fetched page 1 of 49 for modern
# Fetched page 2 of 49 for modern
# Fetched page 3 of 49 for modern
# Fetched page 4 of 49 for modern
# Fetched page 5 of 49 for modern
# Fetched page 6 of 49 for modern
# Fetched page 7 of 49 for modern
# Fetched page 8 of 49 for modern
# Fetched page 9 of 49 for modern
# Fetched page 10 of 49 for modern
# Error fetching data for modern on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=modern&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for modern: 1000
# Fetching artworks for modernist starting from page 1
# Total pages for modernist: 2
# Fetched page 1 of 2 for modernist
# Fetched page 2 of 2 for modernist
# Total artworks retrieved for modernist: 107
# Fetching artworks for Modernism starting from page 1
# Total pages for Modernism: 49
# Fetched page 1 of 49 for Modernism
# Fetched page 2 of 49 for Modernism
# Fetched page 3 of 49 for Modernism
# Fetched page 4 of 49 for Modernism
# Fetched page 5 of 49 for Modernism
# Fetched page 6 of 49 for Modernism
# Fetched page 7 of 49 for Modernism
# Fetched page 8 of 49 for Modernism
# Fetched page 9 of 49 for Modernism
# Fetched page 10 of 49 for Modernism
# Error fetching data for Modernism on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Modernism&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Modernism: 1000
# Fetching artworks for surrealism starting from page 1
# Total pages for surrealism: 2
# Fetched page 1 of 2 for surrealism
# Fetched page 2 of 2 for surrealism
# Total artworks retrieved for surrealism: 190
# Fetching artworks for Surrealism starting from page 1
# Total pages for Surrealism: 2
# Fetched page 1 of 2 for Surrealism
# Fetched page 2 of 2 for Surrealism
# Total artworks retrieved for Surrealism: 190
# Fetching artworks for symbolism starting from page 1
# Total pages for symbolism: 2
# Fetched page 1 of 2 for symbolism
# Fetched page 2 of 2 for symbolism
# Total artworks retrieved for symbolism: 109
# Fetching artworks for Symbolism starting from page 1
# Total pages for Symbolism: 2
# Fetched page 1 of 2 for Symbolism
# Fetched page 2 of 2 for Symbolism
# Total artworks retrieved for Symbolism: 109
# Fetching artworks for Abstract Expressionism starting from page 1
# Total pages for Abstract Expressionism: 7
# Fetched page 1 of 7 for Abstract Expressionism
# Fetched page 2 of 7 for Abstract Expressionism
# Fetched page 3 of 7 for Abstract Expressionism
# Fetched page 4 of 7 for Abstract Expressionism
# Fetched page 5 of 7 for Abstract Expressionism
# Fetched page 6 of 7 for Abstract Expressionism
# Fetched page 7 of 7 for Abstract Expressionism
# Total artworks retrieved for Abstract Expressionism: 662
# Fetching artworks for Neoclassicism starting from page 1
# Total pages for Neoclassicism: 1
# Fetched page 1 of 1 for Neoclassicism
# Total artworks retrieved for Neoclassicism: 52
# Fetching artworks for Rococo starting from page 1
# Total pages for Rococo: 2
# Fetched page 1 of 2 for Rococo
# Fetched page 2 of 2 for Rococo
# Total artworks retrieved for Rococo: 150
# Fetching artworks for Cubism starting from page 1
# Total pages for Cubism: 5
# Fetched page 1 of 5 for Cubism
# Fetched page 2 of 5 for Cubism
# Fetched page 3 of 5 for Cubism
# Fetched page 4 of 5 for Cubism
# Fetched page 5 of 5 for Cubism
# Total artworks retrieved for Cubism: 406
# Fetching artworks for northern renaissance starting from page 1
# Total pages for northern renaissance: 7
# Fetched page 1 of 7 for northern renaissance
# Fetched page 2 of 7 for northern renaissance
# Fetched page 3 of 7 for northern renaissance
# Fetched page 4 of 7 for northern renaissance
# Fetched page 5 of 7 for northern renaissance
# Fetched page 6 of 7 for northern renaissance
# Fetched page 7 of 7 for northern renaissance
# Total artworks retrieved for northern renaissance: 681
# Fetching artworks for Pop art starting from page 1
# Total pages for Pop art: 420
# Fetched page 1 of 420 for Pop art
# Fetched page 2 of 420 for Pop art
# Fetched page 3 of 420 for Pop art
# Fetched page 4 of 420 for Pop art
# Fetched page 5 of 420 for Pop art
# Fetched page 6 of 420 for Pop art
# Fetched page 7 of 420 for Pop art
# Fetched page 8 of 420 for Pop art
# Fetched page 9 of 420 for Pop art
# Fetched page 10 of 420 for Pop art
# Error fetching data for Pop art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Pop+art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Pop art: 1000
# Fetching artworks for Pop Art starting from page 1
# Total pages for Pop Art: 420
# Fetched page 1 of 420 for Pop Art
# Fetched page 2 of 420 for Pop Art
# Fetched page 3 of 420 for Pop Art
# Fetched page 4 of 420 for Pop Art
# Fetched page 5 of 420 for Pop Art
# Fetched page 6 of 420 for Pop Art
# Fetched page 7 of 420 for Pop Art
# Fetched page 8 of 420 for Pop Art
# Fetched page 9 of 420 for Pop Art
# Fetched page 10 of 420 for Pop Art
# Error fetching data for Pop Art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Pop+Art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Pop Art: 1000
# Fetching artworks for mannerism starting from page 1
# Total pages for mannerism: 41
# Fetched page 1 of 41 for mannerism
# Fetched page 2 of 41 for mannerism
# Fetched page 3 of 41 for mannerism
# Fetched page 4 of 41 for mannerism
# Fetched page 5 of 41 for mannerism
# Fetched page 6 of 41 for mannerism
# Fetched page 7 of 41 for mannerism
# Fetched page 8 of 41 for mannerism
# Fetched page 9 of 41 for mannerism
# Fetched page 10 of 41 for mannerism
# Error fetching data for mannerism on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=mannerism&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for mannerism: 1000
# Fetching artworks for late renaissance starting from page 1
# Total pages for late renaissance: 29
# Fetched page 1 of 29 for late renaissance
# Fetched page 2 of 29 for late renaissance
# Fetched page 3 of 29 for late renaissance
# Fetched page 4 of 29 for late renaissance
# Fetched page 5 of 29 for late renaissance
# Fetched page 6 of 29 for late renaissance
# Fetched page 7 of 29 for late renaissance
# Fetched page 8 of 29 for late renaissance
# Fetched page 9 of 29 for late renaissance
# Fetched page 10 of 29 for late renaissance
# Error fetching data for late renaissance on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=late+renaissance&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for late renaissance: 1000
# Fetching artworks for Mannerism starting from page 1
# Total pages for Mannerism: 41
# Fetched page 1 of 41 for Mannerism
# Fetched page 2 of 41 for Mannerism
# Fetched page 3 of 41 for Mannerism
# Fetched page 4 of 41 for Mannerism
# Fetched page 5 of 41 for Mannerism
# Fetched page 6 of 41 for Mannerism
# Fetched page 7 of 41 for Mannerism
# Fetched page 8 of 41 for Mannerism
# Fetched page 9 of 41 for Mannerism
# Fetched page 10 of 41 for Mannerism
# Error fetching data for Mannerism on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Mannerism&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Mannerism: 1000
# Fetching artworks for minimalism starting from page 1
# Total pages for minimalism: 1
# Fetched page 1 of 1 for minimalism
# Total artworks retrieved for minimalism: 17
# Fetching artworks for Minimalism starting from page 1
# Total pages for Minimalism: 1
# Fetched page 1 of 1 for Minimalism
# Total artworks retrieved for Minimalism: 17
# Fetching artworks for Conceptual Art starting from page 1
# Total pages for Conceptual Art: 423
# Fetched page 1 of 423 for Conceptual Art
# Fetched page 2 of 423 for Conceptual Art
# Fetched page 3 of 423 for Conceptual Art
# Fetched page 4 of 423 for Conceptual Art
# Fetched page 5 of 423 for Conceptual Art
# Fetched page 6 of 423 for Conceptual Art
# Fetched page 7 of 423 for Conceptual Art
# Fetched page 8 of 423 for Conceptual Art
# Fetched page 9 of 423 for Conceptual Art
# Fetched page 10 of 423 for Conceptual Art
# Error fetching data for Conceptual Art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Conceptual+Art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Conceptual Art: 1000
# Fetching artworks for Art Informel starting from page 1
# Total pages for Art Informel: 413
# Fetched page 1 of 413 for Art Informel
# Fetched page 2 of 413 for Art Informel
# Fetched page 3 of 413 for Art Informel
# Fetched page 4 of 413 for Art Informel
# Fetched page 5 of 413 for Art Informel
# Fetched page 6 of 413 for Art Informel
# Fetched page 7 of 413 for Art Informel
# Fetched page 8 of 413 for Art Informel
# Fetched page 9 of 413 for Art Informel
# Fetched page 10 of 413 for Art Informel
# Error fetching data for Art Informel on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Art+Informel&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Art Informel: 1000
# Fetching artworks for early renaissance starting from page 1
# Total pages for early renaissance: 29
# Fetched page 1 of 29 for early renaissance
# Fetched page 2 of 29 for early renaissance
# Fetched page 3 of 29 for early renaissance
# Fetched page 4 of 29 for early renaissance
# Fetched page 5 of 29 for early renaissance
# Fetched page 6 of 29 for early renaissance
# Fetched page 7 of 29 for early renaissance
# Fetched page 8 of 29 for early renaissance
# Fetched page 9 of 29 for early renaissance
# Fetched page 10 of 29 for early renaissance
# Error fetching data for early renaissance on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=early+renaissance&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for early renaissance: 1000
# Fetching artworks for ukiyo-e starting from page 1
# Total pages for ukiyo-e: 43
# Fetched page 1 of 43 for ukiyo-e
# Fetched page 2 of 43 for ukiyo-e
# Fetched page 3 of 43 for ukiyo-e
# Fetched page 4 of 43 for ukiyo-e
# Fetched page 5 of 43 for ukiyo-e
# Fetched page 6 of 43 for ukiyo-e
# Fetched page 7 of 43 for ukiyo-e
# Fetched page 8 of 43 for ukiyo-e
# Fetched page 9 of 43 for ukiyo-e
# Fetched page 10 of 43 for ukiyo-e
# Error fetching data for ukiyo-e on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=ukiyo-e&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for ukiyo-e: 1000
# Fetching artworks for Neo-Expressionism starting from page 1
# Total pages for Neo-Expressionism: 1
# Fetched page 1 of 1 for Neo-Expressionism
# Total artworks retrieved for Neo-Expressionism: 20
# Fetching artworks for high renaissance starting from page 1
# Total pages for high renaissance: 5
# Fetched page 1 of 5 for high renaissance
# Fetched page 2 of 5 for high renaissance
# Fetched page 3 of 5 for high renaissance
# Fetched page 4 of 5 for high renaissance
# Fetched page 5 of 5 for high renaissance
# Total artworks retrieved for high renaissance: 448
# Fetching artworks for lyrical abstraction starting from page 1
# Total pages for lyrical abstraction: 7
# Fetched page 1 of 7 for lyrical abstraction
# Fetched page 2 of 7 for lyrical abstraction
# Fetched page 3 of 7 for lyrical abstraction
# Fetched page 4 of 7 for lyrical abstraction
# Fetched page 5 of 7 for lyrical abstraction
# Fetched page 6 of 7 for lyrical abstraction
# Fetched page 7 of 7 for lyrical abstraction
# Total artworks retrieved for lyrical abstraction: 697
# Fetching artworks for Fauvism starting from page 1
# Total pages for Fauvism: 1
# Fetched page 1 of 1 for Fauvism
# Total artworks retrieved for Fauvism: 24
# Fetching artworks for contemporary starting from page 1
# Total pages for contemporary: 33
# Fetched page 1 of 33 for contemporary
# Fetched page 2 of 33 for contemporary
# Fetched page 3 of 33 for contemporary
# Fetched page 4 of 33 for contemporary
# Fetched page 5 of 33 for contemporary
# Fetched page 6 of 33 for contemporary
# Fetched page 7 of 33 for contemporary
# Fetched page 8 of 33 for contemporary
# Fetched page 9 of 33 for contemporary
# Fetched page 10 of 33 for contemporary
# Error fetching data for contemporary on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=contemporary&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for contemporary: 1000
# Fetching artworks for Op Art starting from page 1
# Total pages for Op Art: 419
# Fetched page 1 of 419 for Op Art
# Fetched page 2 of 419 for Op Art
# Fetched page 3 of 419 for Op Art
# Fetched page 4 of 419 for Op Art
# Fetched page 5 of 419 for Op Art
# Fetched page 6 of 419 for Op Art
# Fetched page 7 of 419 for Op Art
# Fetched page 8 of 419 for Op Art
# Fetched page 9 of 419 for Op Art
# Fetched page 10 of 419 for Op Art
# Error fetching data for Op Art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Op+Art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Op Art: 1000
# Fetching artworks for Art Deco starting from page 1
# Total pages for Art Deco: 416
# Fetched page 1 of 416 for Art Deco
# Fetched page 2 of 416 for Art Deco
# Fetched page 3 of 416 for Art Deco
# Fetched page 4 of 416 for Art Deco
# Fetched page 5 of 416 for Art Deco
# Fetched page 6 of 416 for Art Deco
# Fetched page 7 of 416 for Art Deco
# Fetched page 8 of 416 for Art Deco
# Fetched page 9 of 416 for Art Deco
# Fetched page 10 of 416 for Art Deco
# Error fetching data for Art Deco on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Art+Deco&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Art Deco: 1000
# Fetching artworks for postmodern starting from page 1
# Total pages for postmodern: 1
# Fetched page 1 of 1 for postmodern
# Total artworks retrieved for postmodern: 65
# Total number of artworks retrieved: 24215

# %%
full_df.head(10)
# Out:
#   artwork_type_title         style_title      id  \
# 0           Painting       Impressionism   64729
# 1          Sculpture  Post-Impressionism     719
# 2           Painting       Impressionism     138
# 3           Painting       Impressionism   70065
# 4           Painting       Impressionism   90899
# 5           Painting         Pointillism   27992
# 6           Painting  Post-Impressionism   13763
# 7           Painting       Impressionism  111326
# 8           Painting       Impressionism   71573
# 9              Print  Post-Impressionism   17229
#
#                                image_id                               title  \
# 0  ef96e79b-f481-8114-0804-4bd39c101983       Early Morning, Tarpon Springs
# 1  d0a72b06-f1ee-4464-d58c-5e39bc0534b3   A Burgher of Calais (Jean d'Aire)
# 2  e72305c9-1a1c-8a36-7450-582619366338              Flower Girl in Holland
# 3  2e796bd8-4e0b-f55a-7c69-75a70a3e97d7                           Afterglow
# 4  9604cbbd-722b-8de3-e7cc-4a80be648d79              Lady in Green and Gray
# 5  2d484387-2509-5e8e-2c43-22f9981972eb  A Sunday on La Grande Jatte — 1884
# 6  045a1779-36a4-282f-49b8-b8fb007f8254                  Snow-Crowned Hills
# 7  6f92b799-de7c-7603-3644-3934563703f2              The Hippodrome, London
# 8  a67c4473-57a4-9807-a94e-1136d3daf876                           A Holiday
# 9  3b374643-5328-3e00-c02b-5ab56e5ae8f8                          The Scream
#
#      search_term
# 0  Impressionism
# 1  Impressionism
# 2  Impressionism
# 3  Impressionism
# 4  Impressionism
# 5  Impressionism
# 6  Impressionism
# 7  Impressionism
# 8  Impressionism
# 9  Impressionism

# %%
full_df['artwork_type_title'].value_counts()
# Out:
# artwork_type_title
# Painting                   6739
# Print                      4240
# Sculpture                  2392
# Photograph                 2227
# Vessel                     1641
# Drawing and Watercolor     1227
# Textile                     737
# Coin                        698
# Decorative Arts             669
# Costume and Accessories     461
# Ceramics                    408
# Architectural Drawing       318
# Furniture                   315
# Metalwork                   278
# Mixed Media                 238
# Book                        171
# Mask                        171
# Graphic Design              156
# Glass                       153
# Design                      140
# Film, Video, New Media      117
# Religious/Ritual Object     110
# Architectural fragment      100
# Installation                 96
# Armor                        66
# Miniature room               62
# Arms                         61
# Funerary Object              53
# Archives (groupings)         43
# Model                        41
# Basketry                     30
# Coverings and Hangings       21
# Furnishings                  14
# Miniature Painting            9
# Time Based Media              4
# Icon                          4
# non-art                       2
# Name: count, dtype: int64

# %% [markdown]
# Now filter for only paintings

# %%
filtered_full_df = full_df[full_df['artwork_type_title'] == 'Painting']
filtered_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6739 entries, 0 to 24125
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artwork_type_title  6739 non-null   object
#  1   style_title         3550 non-null   object
#  2   id                  6739 non-null   int64
#  3   image_id            6679 non-null   object
#  4   title               6739 non-null   object
#  5   search_term         6739 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 368.5+ KB

# %%
filtered_full_df.isna().sum()
# Out:
# artwork_type_title       0
# style_title           3189
# id                       0
# image_id                60
# title                    0
# search_term              0
# dtype: int64

# %% [markdown]
# Download the images we want.

# %%
import logging
import os
import time
from urllib.parse import urljoin
import requests
import pandas as pd

BASE_URL = "https://www.artic.edu/iiif/2/"
RATE_LIMIT = 60  # requests per minute
IMAGE_QUALITY = "full"
IMAGE_FORMAT = "jpg"
OUTPUT_DIR = 'downloaded_images'
MAX_RETRIES = 2  # Retry up to 2 times if the content is empty or there are errors
RETRY_DELAY = 2  # Delay (in seconds) between retries
REQUEST_DELAY = 1  # Delay (in seconds) between each request

# Set up logging
logging.basicConfig(filename='image_download.log', level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s', datefmt='%d-%b-%y %H:%M:%S')

def download_image(image_id, output_path):
    if not image_id:
        return False, "No image ID provided"
    
    url = urljoin(BASE_URL, f"{image_id}/full/{IMAGE_QUALITY}/0/default.{IMAGE_FORMAT}")
    for attempt in range(MAX_RETRIES + 1):  # Attempt download + retries
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()  # Raises an HTTPError for bad responses
            
            # Log content length and headers
            content_length = len(response.content)
            logging.info(f"Attempt {attempt + 1} - Content length: {content_length}, Headers: {response.headers}")
            
            # Check for non-empty content
            if content_length > 0:
                with open(output_path, 'wb') as f:
                    f.write(response.content)
                
                # Check that the file was written and is not empty
                if os.path.exists(output_path) and os.path.getsize(output_path) > 0:
                    return True, "Success"
                else:
                    logging.warning(f"Downloaded file {output_path} is empty.")
            else:
                logging.warning(f"Attempt {attempt + 1} - Empty content for {image_id}")
        
        except requests.exceptions.HTTPError as e:
            return False, f"HTTP error: {e}"
        except requests.exceptions.ConnectionError as e:
            return False, f"Connection error: {e}"
        except requests.exceptions.Timeout as e:
            return False, f"Timeout error: {e}"
        except requests.exceptions.RequestException as e:
            return False, f"Error downloading: {e}"

        # Wait before retrying if not the last attempt
        if attempt < MAX_RETRIES:
            logging.info(f"Retrying in {RETRY_DELAY} seconds (attempt {attempt + 2}) for {image_id}")
            time.sleep(RETRY_DELAY)

    return False, "Failed after maximum retries"

def download_all_images(df):
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    file_names = []
    total_images = len(df)
    successful_downloads = 0
    failed_downloads = 0
    skipped_downloads = 0
    
    for index, row in df.iterrows():
        image_id = row['image_id']
        if pd.isna(image_id) or not image_id:
            file_names.append(None)
            skipped_downloads += 1
            logging.warning(f"Skipped image at index {index}: No valid image_id")
            continue

        file_name = f"{image_id}.{IMAGE_FORMAT}"
        output_path = os.path.join(OUTPUT_DIR, file_name)

        success, message = download_image(image_id, output_path)
        if success:
            file_names.append(file_name)
            successful_downloads += 1
            logging.info(f"Downloaded: {file_name}")
        else:
            file_names.append(None)
            failed_downloads += 1
            logging.warning(f"Failed to download {image_id}: {message}")

        # Print progress every 100 images
        if (index + 1) % 100 == 0:
            print(f"Progress: {index + 1}/{total_images} images processed")
            print(f"Successful downloads: {successful_downloads}")
            print(f"Failed downloads: {failed_downloads}")
            print(f"Skipped downloads: {skipped_downloads}")
            logging.info(f"Progress: {index + 1}/{total_images} images processed. "
                         f"Successful: {successful_downloads}, Failed: {failed_downloads}, Skipped: {skipped_downloads}")

        # Throttle to respect rate limit and add a 1-second delay between requests
        time.sleep(1)

    return file_names, successful_downloads, failed_downloads, skipped_downloads

# Assuming filtered_full_df is your DataFrame
file_names, successful, failed, skipped = download_all_images(filtered_full_df)
filtered_full_df['file_name'] = file_names

print(f"Image download complete. Total successful downloads: {successful}, "
      f"Total failed: {failed}, Total skipped: {skipped}")
logging.info(f"Process completed. Successful downloads: {successful}, "
             f"Failed downloads: {failed}, Skipped downloads: {skipped}")
# Out:
# Progress: 100/6739 images processed
# Successful downloads: 79
# Failed downloads: 0
# Skipped downloads: 0
# Progress: 200/6739 images processed
# Successful downloads: 155
# Failed downloads: 0
# Skipped downloads: 0
# Progress: 300/6739 images processed
# Successful downloads: 250
# Failed downloads: 0
# Skipped downloads: 0
# Progress: 600/6739 images processed
# Successful downloads: 337
# Failed downloads: 0
# Skipped downloads: 0
# Progress: 2000/6739 images processed
# Successful downloads: 406
# Failed downloads: 0
# Skipped downloads: 1
# Progress: 2200/6739 images processed
# Successful downloads: 424
# Failed downloads: 0
# Skipped downloads: 2
# Progress: 2700/6739 images processed
# Successful downloads: 511
# Failed downloads: 0
# Skipped downloads: 2
# Progress: 2800/6739 images processed
# Successful downloads: 584
# Failed downloads: 0
# Skipped downloads: 2
# Progress: 2900/6739 images processed
# Successful downloads: 656
# Failed downloads: 0
# Skipped downloads: 2
# Progress: 3100/6739 images processed
# Successful downloads: 728
# Failed downloads: 1
# Skipped downloads: 2
# Progress: 3400/6739 images processed
# Successful downloads: 825
# Failed downloads: 5
# Skipped downloads: 2
# Progress: 3500/6739 images processed
# Successful downloads: 901
# Failed downloads: 5
# Skipped downloads: 2
# Progress: 3900/6739 images processed
# Successful downloads: 1141
# Failed downloads: 12
# Skipped downloads: 4
# Progress: 4000/6739 images processed
# Successful downloads: 1210
# Failed downloads: 12
# Skipped downloads: 4
# Progress: 4100/6739 images processed
# Successful downloads: 1280
# Failed downloads: 12
# Skipped downloads: 5
# Progress: 4300/6739 images processed
# Successful downloads: 1416
# Failed downloads: 12
# Skipped downloads: 7
# Progress: 4400/6739 images processed
# Successful downloads: 1498
# Failed downloads: 12
# Skipped downloads: 7
# Progress: 4500/6739 images processed
# Successful downloads: 1572
# Failed downloads: 14
# Skipped downloads: 7
# Progress: 4600/6739 images processed
# Successful downloads: 1645
# Failed downloads: 14
# Skipped downloads: 7
# Progress: 4700/6739 images processed
# Successful downloads: 1711
# Failed downloads: 15
# Skipped downloads: 7
# Progress: 4900/6739 images processed
# Successful downloads: 1821
# Failed downloads: 18
# Skipped downloads: 8
# Progress: 5000/6739 images processed
# Successful downloads: 1880
# Failed downloads: 18
# Skipped downloads: 8
# Progress: 5200/6739 images processed
# Successful downloads: 2010
# Failed downloads: 18
# Skipped downloads: 10
# Progress: 5400/6739 images processed
# Successful downloads: 2145
# Failed downloads: 20
# Skipped downloads: 12
# Progress: 5600/6739 images processed
# Successful downloads: 2282
# Failed downloads: 21
# Skipped downloads: 13
# Progress: 5800/6739 images processed
# Successful downloads: 2416
# Failed downloads: 22
# Skipped downloads: 13
# Progress: 5900/6739 images processed
# Successful downloads: 2469
# Failed downloads: 24
# Skipped downloads: 14
# Progress: 6000/6739 images processed
# Successful downloads: 2535
# Failed downloads: 24
# Skipped downloads: 14
# Progress: 6100/6739 images processed
# Successful downloads: 2603
# Failed downloads: 24
# Skipped downloads: 15
# Progress: 6300/6739 images processed
# Successful downloads: 2741
# Failed downloads: 24
# Skipped downloads: 18
# Progress: 6400/6739 images processed
# Successful downloads: 2823
# Failed downloads: 24
# Skipped downloads: 18
# Progress: 6500/6739 images processed
# Successful downloads: 2896
# Failed downloads: 26
# Skipped downloads: 18
# Progress: 6600/6739 images processed
# Successful downloads: 2969
# Failed downloads: 26
# Skipped downloads: 18
# Progress: 6900/6739 images processed
# Successful downloads: 3145
# Failed downloads: 30
# Skipped downloads: 19
# Progress: 7000/6739 images processed
# Successful downloads: 3202
# Failed downloads: 30
# Skipped downloads: 19
# Progress: 7200/6739 images processed
# Successful downloads: 3333
# Failed downloads: 30
# Skipped downloads: 21
# Progress: 7400/6739 images processed
# Successful downloads: 3394
# Failed downloads: 30
# Skipped downloads: 22
# Progress: 7500/6739 images processed
# Successful downloads: 3479
# Failed downloads: 30
# Skipped downloads: 22
# Progress: 7600/6739 images processed
# Successful downloads: 3551
# Failed downloads: 32
# Skipped downloads: 22
# Progress: 7700/6739 images processed
# Successful downloads: 3625
# Failed downloads: 32
# Skipped downloads: 22
# Progress: 8000/6739 images processed
# Successful downloads: 3802
# Failed downloads: 36
# Skipped downloads: 23
# Progress: 8200/6739 images processed
# Successful downloads: 3928
# Failed downloads: 36
# Skipped downloads: 25
# Progress: 8300/6739 images processed
# Successful downloads: 3989
# Failed downloads: 36
# Skipped downloads: 25
# Progress: 8500/6739 images processed
# Successful downloads: 4092
# Failed downloads: 36
# Skipped downloads: 28
# Progress: 8600/6739 images processed
# Successful downloads: 4120
# Failed downloads: 36
# Skipped downloads: 28
# Progress: 9100/6739 images processed
# Successful downloads: 4247
# Failed downloads: 37
# Skipped downloads: 29
# Progress: 9900/6739 images processed
# Successful downloads: 4385
# Failed downloads: 38
# Skipped downloads: 35
# Progress: 12700/6739 images processed
# Successful downloads: 4580
# Failed downloads: 46
# Skipped downloads: 38
# Progress: 12800/6739 images processed
# Successful downloads: 4601
# Failed downloads: 46
# Skipped downloads: 38
# Progress: 13700/6739 images processed
# Successful downloads: 4711
# Failed downloads: 47
# Skipped downloads: 38
# Progress: 16700/6739 images processed
# Successful downloads: 5008
# Failed downloads: 48
# Skipped downloads: 43
# Progress: 16800/6739 images processed
# Successful downloads: 5027
# Failed downloads: 49
# Skipped downloads: 43
# Progress: 16900/6739 images processed
# Successful downloads: 5062
# Failed downloads: 49
# Skipped downloads: 43
# Progress: 17100/6739 images processed
# Successful downloads: 5097
# Failed downloads: 51
# Skipped downloads: 44
# Progress: 17300/6739 images processed
# Successful downloads: 5140
# Failed downloads: 51
# Skipped downloads: 44
# Progress: 17700/6739 images processed
# Successful downloads: 5253
# Failed downloads: 53
# Skipped downloads: 44
# Progress: 19100/6739 images processed
# Successful downloads: 5418
# Failed downloads: 56
# Skipped downloads: 47
# Progress: 19700/6739 images processed
# Successful downloads: 5439
# Failed downloads: 56
# Skipped downloads: 48
# Progress: 20600/6739 images processed
# Successful downloads: 5618
# Failed downloads: 57
# Skipped downloads: 48
# Progress: 21200/6739 images processed
# Successful downloads: 5722
# Failed downloads: 58
# Skipped downloads: 54
# Progress: 21300/6739 images processed
# Successful downloads: 5795
# Failed downloads: 60
# Skipped downloads: 54
# Progress: 21400/6739 images processed
# Successful downloads: 5864
# Failed downloads: 60
# Skipped downloads: 54
# Progress: 21500/6739 images processed
# Successful downloads: 5923
# Failed downloads: 61
# Skipped downloads: 54
# Progress: 21600/6739 images processed
# Successful downloads: 5984
# Failed downloads: 62
# Skipped downloads: 55
# Progress: 21700/6739 images processed
# Successful downloads: 6045
# Failed downloads: 64
# Skipped downloads: 55
# Progress: 21800/6739 images processed
# Successful downloads: 6108
# Failed downloads: 65
# Skipped downloads: 55
# Progress: 21900/6739 images processed
# Successful downloads: 6182
# Failed downloads: 65
# Skipped downloads: 57
# Progress: 22500/6739 images processed
# Successful downloads: 6400
# Failed downloads: 66
# Skipped downloads: 59
# Progress: 22600/6739 images processed
# Successful downloads: 6424
# Failed downloads: 66
# Skipped downloads: 59
# Progress: 23000/6739 images processed
# Successful downloads: 6537
# Failed downloads: 68
# Skipped downloads: 59
# Progress: 23400/6739 images processed
# Successful downloads: 6583
# Failed downloads: 69
# Skipped downloads: 59
# Image download complete. Total successful downloads: 6610, Total failed: 69, Total skipped: 60
# C:\Users\16148\AppData\Local\Temp\ipykernel_11552\4046572947.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_full_df['file_name'] = file_names

# %%
filtered_full_df.head()
# Out:
#   artwork_type_title    style_title     id  \
# 0           Painting  Impressionism  64729
# 2           Painting  Impressionism    138
# 3           Painting  Impressionism  70065
# 4           Painting  Impressionism  90899
# 5           Painting    Pointillism  27992
#
#                                image_id                               title  \
# 0  ef96e79b-f481-8114-0804-4bd39c101983       Early Morning, Tarpon Springs
# 2  e72305c9-1a1c-8a36-7450-582619366338              Flower Girl in Holland
# 3  2e796bd8-4e0b-f55a-7c69-75a70a3e97d7                           Afterglow
# 4  9604cbbd-722b-8de3-e7cc-4a80be648d79              Lady in Green and Gray
# 5  2d484387-2509-5e8e-2c43-22f9981972eb  A Sunday on La Grande Jatte — 1884
#
#      search_term                                 file_name
# 0  Impressionism  ef96e79b-f481-8114-0804-4bd39c101983.jpg
# 2  Impressionism  e72305c9-1a1c-8a36-7450-582619366338.jpg
# 3  Impressionism  2e796bd8-4e0b-f55a-7c69-75a70a3e97d7.jpg
# 4  Impressionism  9604cbbd-722b-8de3-e7cc-4a80be648d79.jpg
# 5  Impressionism  2d484387-2509-5e8e-2c43-22f9981972eb.jpg

# %%
filtered_full_df.to_csv("images_dataframe.csv", index=False)
