# %%
import json
import logging
import os
import time
from io import BytesIO
from urllib.parse import urljoin

import numpy as np
import pandas as pd
import requests
from dotenv import load_dotenv
from PIL import Image
from ratelimit import limits, sleep_and_retry
from tqdm import tqdm
from requests.exceptions import RequestException

# %%
# Create list of styles to use:

top_styles = [
    "Impressionism",
    "Realism",
    "Romanticism",
    "Expressionism",
    "Post-Impressionism",
    "Baroque",
    "Art Nouveau (Modern)",
    "Surrealism",
    "Symbolism",
    "Abstract Expressionism",
    "Neoclassicism",
    "Rococo",
    "Cubism",
    "Northern Renaissance",
    "Academicism",
    "Pop Art",
    "Mannerism (Late Renaissance)",
    "Minimalism",
    "Conceptual Art",
    "Abstract Art",
    "Art Informel",
    "Early Renaissance",
    "Ukiyo-e",
    "Neo-Expressionism",
    "High Renaissance",
    "Color Field Painting",
    "Orientalism",
    "Lyrical Abstraction",
    "Fauvism",
    "Contemporary",
    "Op Art",
    "Neo-Impressionism",
    "Art-Deco",
]

# %%
# Load and examine the csv of all artwork pieces from the AIC
all_df = pd.read_csv("all_artworks_aic.csv", low_memory=False)

# %%
all_df['artwork_type_title'].value_counts()
# Out:
# artwork_type_title
# Print                      45468
# Photograph                 25346
# Drawing and Watercolor     14697
# Textile                     9825
# Painting                    3916
# Vessel                      3578
# Architectural Drawing       3435
# Book                        3243
# Coin                        2783
# Costume and Accessories     2518
# Glass                       2364
# Sculpture                   2314
# Ceramics                    2055
# Decorative Arts             1468
# Metalwork                   1292
# Graphic Design              1134
# Design                       771
# Arms                         637
# Furniture                    587
# Religious/Ritual Object      481
# Armor                        430
# Architectural fragment       286
# Archives (groupings)         210
# Mixed Media                  187
# Model                        176
# Coverings and Hangings       171
# non-art                      163
# Film, Video, New Media       163
# Mask                          82
# Miniature room                69
# Funerary Object               67
# Installation                  59
# Basketry                      46
# Time Based Media              40
# Miniature Painting            22
# Furnishings                   19
# Medals                        10
# Audio-Video                    2
# Equipment                      2
# Materials                      1
# Icon                           1
# Digital Arts                   1
# Prototypes                     1
# Name: count, dtype: int64

# %%
all_df['style_titles'].value_counts()
# Out:
# style_titles
# []                                                                                           95963
# ['Japanese (culture or style)']                                                               7766
# ['21st Century']                                                                              4391
# ['19th century']                                                                              3997
# ['20th Century']                                                                              3113
#                                                                                              ...
# ['maninka', 'Arts of Africa', 'african Art', 'Northern Africa and the Sahel']                    1
# ['hausa', 'Arts of Africa', 'african Art', 'Northern Africa and the Sahel']                      1
# ['shona', 'Arts of Africa', 'african Art', 'Eastern and Southern Africa']                        1
# ['gwembe tonga', 'Arts of Africa', 'african Art', 'tonga', 'Eastern and Southern Africa']        1
# ['late period (egyptian)', 'saite period', 'twenty-sixth dynasty']                               1
# Name: count, Length: 2074, dtype: int64

# %%
all_df['style_title'].value_counts()
# Out:
# style_title
# Japanese (culture or style)    7864
# 21st Century                   4531
# 19th century                   4042
# 20th Century                   3154
# Chinese (culture or style)     1859
#                                ...
# native north american             1
# Abstraction                       1
# eskimo                            1
# Neogothique                       1
# heriz                             1
# Name: count, Length: 610, dtype: int64

# %%
full_list = all_df['style_title'].dropna().to_list()
full_list
# Out:
# ['Surrealism',
#  'South Asian',
#  'South Asian',
#  'South Asian',
#  'Himalayan',
#  'Impressionism',
#  'Japanese (culture or style)',
#  '21st Century',
#  'Japanese (culture or style)',
#  '20th Century',
#  'nineteenth century',
#  'nineteenth century',
#  'imperial (roman)',
#  '18th Century',
#  '18th Century',
#  '21st Century',
#  '21st Century',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  'Pictorialism',
#  '19th century',
#  '19th century',
#  '19th century',
#  'Impressionism',
#  'Modernism',
#  '21st Century',
#  '19th century',
#  '21st Century',
#  '17th Century',
#  'asante',
#  'aymará',
#  'aymará',
#  'aymará',
#  'empire',
#  '18th Century',
#  'empire',
#  'empire',
#  '20th Century',
#  'bauhaus',
#  'contemporary',
#  'Pop Art',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '19th century',
#  '19th century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Surrealism',
#  'Surrealism',
#  '17th Century',
#  '16th Century',
#  'sixteenth century',
#  '16th Century',
#  '16th Century',
#  '16th Century',
#  'nineteenth century',
#  '19th century',
#  '19th century',
#  '19th century',
#  'nineteenth century',
#  '15th century',
#  '19th century',
#  '17th Century',
#  '17th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'contemporary',
#  'Arts and Crafts Movement',
#  'Post-Impressionism',
#  'Japanese (culture or style)',
#  'South Asian',
#  'South Asian',
#  'saveh',
#  'Folk Art',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'imperial (roman)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'bauhaus',
#  '21st Century',
#  '21st Century',
#  'Chinese (culture or style)',
#  'Japanese (culture or style)',
#  'showa',
#  '20th Century',
#  'Art Deco',
#  'Art Deco',
#  'Art Deco',
#  'Modernism',
#  'Modernism',
#  'mamluk',
#  'mamluk',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Japanism',
#  'asante',
#  'nupe',
#  'yoruba',
#  'yoruba',
#  '20th Century',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Folk Art',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  'Modernism',
#  'Pop Art',
#  '21st Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'niger delta',
#  'Photo League',
#  'Pictorialism',
#  '20th Century',
#  'avant-garde',
#  '19th century',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  'avant-garde',
#  '19th century',
#  '20th Century',
#  '20th Century',
#  'kuba (democratic republic of congo style',
#  'Southeast Asian',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'chinese export',
#  '18th Century',
#  'South Asian',
#  'Southeast Asian',
#  'Southeast Asian',
#  'Southeast Asian',
#  'Southeast Asian',
#  'Southeast Asian',
#  'Southeast Asian',
#  'Southeast Asian',
#  'Japanese (culture or style)',
#  'Surrealism',
#  '19th century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '21st Century',
#  'imperial (roman)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'late classical',
#  'apulian',
#  'apulian',
#  'Japanese (culture or style)',
#  'nineteenth century',
#  '15th century',
#  'sixteenth century',
#  'nineteenth century',
#  '15th century',
#  '15th century',
#  '15th century',
#  '20th Century',
#  'nineteenth century',
#  'nineteenth century',
#  '17th Century',
#  '20th Century',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Arts and Crafts Movement',
#  '19th century',
#  '18th Century',
#  'Modernism',
#  'chancay',
#  'avant-garde',
#  '18th Century',
#  'Pop Art',
#  'fon',
#  'Prairie School',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Modernism',
#  '19th century',
#  'Arts and Crafts Movement',
#  'Arts and Crafts Movement',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'roman period (egyptian)',
#  'roman period (egyptian)',
#  'Neoclassicism',
#  'yoruba',
#  'medieval',
#  'medieval',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'constantinian',
#  'Japanese (culture or style)',
#  'Realism',
#  'Folk Art',
#  '20th Century',
#  '20th Century',
#  'sixteenth century',
#  '20th Century',
#  '18th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Arts and Crafts Movement',
#  'Arts and Crafts Movement',
#  'Rococo',
#  'Japanism',
#  'nineteenth century',
#  '18th Century',
#  '19th century',
#  '18th Century',
#  '18th Century',
#  '19th century',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'Modernism',
#  'yoruba',
#  'asante',
#  'yoruba',
#  'parthian',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'chancay',
#  'chancay',
#  'chancay',
#  'chancay',
#  'chancay',
#  'chimú',
#  'parthian',
#  'nupe',
#  'nupe',
#  'parthian',
#  'Realism',
#  'Arts and Crafts Movement',
#  'Modernism',
#  'Impressionism',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  'parthian',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '20th Century',
#  '19th century',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  'New Bauhaus (Institute of Design)',
#  '19th century',
#  '19th century',
#  '19th century',
#  '20th Century',
#  'Prairie School',
#  '20th Century',
#  '20th Century',
#  'South Asian',
#  'South Asian',
#  'Southeast Asian',
#  'sarouk',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  'early etruscan',
#  'Himalayan',
#  'Japanese (culture or style)',
#  'Art Deco',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Baroque',
#  'Modernism',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'nineteenth century',
#  'Himalayan',
#  'Himalayan',
#  'Chinese (culture or style)',
#  'Southeast Asian',
#  'South Asian',
#  'Surrealism',
#  'medieval',
#  'medieval',
#  'chinoiserie',
#  'Renaissance',
#  '19th century',
#  '19th century',
#  '19th century',
#  'Pictorialism',
#  '19th century',
#  '19th century',
#  'Pictorialism',
#  '19th century',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  '19th century',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  '19th century',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  'Pictorialism',
#  '19th century',
#  '19th century',
#  'byzantine',
#  'byzantine',
#  'byzantine',
#  'ptolemaic',
#  'ptolemaic',
#  '20th Century',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Rococo',
#  'baule',
#  '"bizarre" style',
#  'Arts and Crafts Movement',
#  'medieval',
#  '"bizarre" style',
#  '"bizarre" style',
#  'Arts and Crafts Movement',
#  'Modernism',
#  'Modernism',
#  'empire',
#  'empire',
#  'Chinese (culture or style)',
#  'peruvian',
#  'Modernism',
#  'Modernism',
#  '19th century',
#  'chimú',
#  'Modernism',
#  'Modernism',
#  'Arts and Crafts Movement',
#  'Chinese (culture or style)',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'kuba (democratic republic of congo style',
#  'Modernism',
#  '19th century',
#  '19th century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'South Asian',
#  'Art Deco',
#  '19th century',
#  'Arts and Crafts Movement',
#  'nineteenth century',
#  '18th Century',
#  'Japanese (culture or style)',
#  '21st Century',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Folk Art',
#  'Cubism',
#  'talavera',
#  '20th Century',
#  'spanish colonial',
#  'Modernism',
#  'Arts and Crafts Movement',
#  'studio pottery',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Prairie School',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Japanese (culture or style)',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Japanese (culture or style)',
#  'Chinese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Chinese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'spanish colonial',
#  'chinoiserie',
#  'Modernism',
#  'Modernism',
#  'Art Nouveau',
#  'Modernism',
#  'Modernism',
#  'empire',
#  'empire',
#  'empire',
#  'empire',
#  'empire',
#  'Japanese (culture or style)',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Art Deco',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Japanese (culture or style)',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Japanese (culture or style)',
#  'spanish colonial',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'asante',
#  'asante',
#  'Rococo',
#  '20th Century',
#  'Arts and Crafts Movement',
#  'Japanese (culture or style)',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'spanish colonial',
#  'Japanese (culture or style)',
#  '20th Century',
#  'adam style',
#  'avant-garde',
#  'qing',
#  'bauhaus',
#  'bauhaus',
#  'bauhaus',
#  'Cubism',
#  'spanish colonial',
#  'san ildefonso',
#  'qing',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Himalayan',
#  'Himalayan',
#  'Himalayan',
#  'Himalayan',
#  'Southeast Asian',
#  'qing',
#  'Himalayan',
#  'Himalayan',
#  'Himalayan',
#  'South Asian',
#  'roman (ancient, style or period)',
#  'imperial (roman)',
#  'Japanese (culture or style)',
#  'Japanism',
#  'South Asian',
#  'South Asian',
#  'spanish colonial',
#  'Pop Art',
#  '20th Century',
#  '20th Century',
#  'Chinese (culture or style)',
#  'sixteenth century',
#  'Modernism',
#  'aymará',
#  '19th century',
#  'Arts and Crafts Movement',
#  'empire',
#  '19th century',
#  'Modernism',
#  'spanish colonial',
#  'Modernism',
#  'Modernism',
#  '21st Century',
#  '21st Century',
#  '21st Century',
#  '21st Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '21st Century',
#  '20th Century',
#  'empire',
#  '21st Century',
#  'spanish colonial',
#  'Prairie School',
#  '20th Century',
#  '20th Century',
#  '21st Century',
#  'Chinese (culture or style)',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Cubism',
#  'Modernism',
#  'bauhaus',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Prairie School',
#  'Impressionism',
#  'Photo League',
#  'empire',
#  'Folk Art',
#  'Art Deco',
#  'Impressionism',
#  'Photo League',
#  '19th century',
#  'Pictorialism',
#  'Pictorialism',
#  'spanish colonial',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'spanish colonial',
#  'Modernism',
#  'Impressionism',
#  'Impressionism',
#  '17th Century',
#  '18th Century',
#  '21st Century',
#  'Cubism',
#  'Surrealism',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  '20th Century',
#  'red-figure',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  'Chinese (culture or style)',
#  '18th Century',
#  'nineteenth century',
#  '19th century',
#  '18th Century',
#  'chimú',
#  '18th Century',
#  'spanish colonial',
#  'spanish colonial',
#  'medieval',
#  'Japanese (culture or style)',
#  'Chinese (culture or style)',
#  'nayarit',
#  'colima',
#  'Modernism',
#  '19th century',
#  'isfahan',
#  '17th Century',
#  'isfahan',
#  'Chinese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Japanese (culture or style)',
#  'Chinese (culture or style)',
#  'Japanese (culture or style)',
#  '17th Century',
#  'spanish colonial',
#  'spanish colonial',
#  'Folk Art',
#  'isfahan',
#  'Japanese (culture or style)',
#  'chinese export',
#  'Japanese (culture or style)',
#  'kuba (democratic republic of congo style',
#  'ottoman',
#  'Gothic (medieval)',
#  'Islamic',
#  'Islamic',
#  'spanish colonial',
#  'pueblo',
#  'Impressionism',
#  'medieval',
#  'medieval',
#  'spanish colonial',
#  'talavera',
#  'talavera',
#  'talavera',
#  'talavera',
#  'maya',
#  'talavera',
#  '20th Century',
#  'Realism',
#  'Realism',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'talavera',
#  '20th Century',
#  '20th Century',
#  'maya',
#  'maya',
#  'secession movement',
#  '20th Century',
#  'Folk Art',
#  '20th Century',
#  '20th Century',
#  'medieval',
#  'medieval',
#  'medieval',
#  'medieval',
#  'medieval',
#  'medieval',
#  'medieval',
#  'chinese export',
#  'talavera',
#  'chinese export',
#  'talavera',
#  'Modernism',
#  'nazca',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Cubism',
#  'spanish colonial',
#  '20th Century',
#  '20th Century',
#  '20th Century',
#  'Modernism',
#  'Arts and Crafts Movement',
#  'Art Nouveau',
#  'Modernism',
#  'georgian',
#  'georgian',
#  'victorian',
#  'spanish colonial',
#  'georgian',
#  'georgian',
#  'georgian',
#  'talavera',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'Modernism',
#  'georgian',
#  'talavera',
#  'nineteenth century',
#  '18th Century',
#  '18th Century',
#  'Impressionism',
#  'Japanese (culture or style)',
#  '16th Century',
#  'Modernism',
#  ...]

# %%
# Combine single style_title and multiple style_titles
all_styles = set() 

# Add styles from style_title column (single style per artwork)
all_styles.update(all_df['style_title'].dropna().unique())

# Add styles from style_titles column (multiple styles per artwork)
for style_list in all_df['style_titles'].dropna():
    if isinstance(style_list, list):  # Ensure it's a list
        all_styles.update(style_list)  # Add all styles from the list

# Convert back to list to preserve order if needed
unique_styles = list(all_styles)

print(f"Total number of unique styles: {len(unique_styles)}")
# Out:
# Total number of unique styles: 610

# %%
def check_top_styles(style_titles, top_styles):
    # Convert all style_titles to lowercase for case-insensitive comparison
    style_titles_lower = [title.lower() for title in style_titles]
    
    # Check each top style
    not_found = []
    found = {}
    
    for style in top_styles:
        style_lower = style.lower()
        matches = []
        
        for i, title_lower in enumerate(style_titles_lower):
            if style_lower == title_lower:
                matches.append(style_titles[i])
            elif (style_lower == "art-deco" and "art deco" in title_lower) or \
                 (style_lower == "mannerism (late renaissance)" and ("mannerism" in title_lower or "late renaissance" in title_lower)) or \
                 (style_lower == "romanticism" and "romantic" in title_lower) or \
                 (style_lower == "art nouveau (modern)" and title_lower in ["modern art", "modern", "modernist", "modernism"]) or \
                 (style_lower == "abstract art" and "abstract" in title_lower) or \
                 (style_lower == "neo-impressionism" and ("neo impressionism" in title_lower or "neo-impressionism" in title_lower)):
                matches.append(style_titles[i])

        
        if matches:
            found[style] = matches
        else:
            not_found.append(style)
    
    # Print results
    if not_found:
        print("The following styles were not found in the df:")
        for style in not_found:
            print(f"- {style}")
    else:
        print("All top styles were found in the df.")
    
    print("\nMatches found:")
    for style, matches in found.items():
        print(f"{style}:")
        for match in matches:
            print(f"  - {match}")
    
    # Print summary
    print(f"\nFound {len(found)} out of {len(top_styles)} top styles.")
    
    return found

# Usage
found_styles = check_top_styles(unique_styles, top_styles)
# Out:
# The following styles were not found in the df:
# - Northern Renaissance
# - Academicism
# - Art Informel
# - Ukiyo-e
# - Neo-Expressionism
# - High Renaissance
# - Color Field Painting
# - Orientalism
# - Lyrical Abstraction
# - Neo-Impressionism
#
# Matches found:
# Impressionism:
#   - Impressionism
# Realism:
#   - Realism
# Romanticism:
#   - romantic
#   - neo-romantic
# Expressionism:
#   - Expressionism
# Post-Impressionism:
#   - Post-Impressionism
# Baroque:
#   - Baroque
# Art Nouveau (Modern):
#   - Modernism
#   - Modern Art
# Surrealism:
#   - Surrealism
# Symbolism:
#   - Symbolism
# Abstract Expressionism:
#   - Abstract Expressionism
# Neoclassicism:
#   - Neoclassicism
# Rococo:
#   - Rococo
# Cubism:
#   - Cubism
# Pop Art:
#   - Pop Art
# Mannerism (Late Renaissance):
#   - Mannerism
# Minimalism:
#   - Minimalism
# Conceptual Art:
#   - Conceptual Art
# Abstract Art:
#   - Abstract Expressionism
#   - Abstract
#   - Abstraction
# Early Renaissance:
#   - early renaissance
# Fauvism:
#   - Fauvism
# Contemporary:
#   - contemporary
# Op Art:
#   - Op Art
# Art-Deco:
#   - Art Deco
#
# Found 23 out of 33 top styles.

# %% [markdown]
# Only only finding 23 of 33 styles, I decided to examine the results if I did search the API instead of
# using the data dump.

# %%
def get_all_style_titles():
    base_url = "https://api.artic.edu/api/v1/category-terms"
    all_titles = set() 
    page = 1
    limit = 100  # Maximum allowed by the API

    while True:
        params = {
            "fields": "id,title",
            "limit": limit,
            "page": page,
            "query[term][category]": "Style",
            "sort": "title"
        }
        
        response = requests.get(base_url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            new_titles = [item['title'] for item in data['data']]
            all_titles.update(new_titles)
            
            # Check if we've reached the last page
            if len(new_titles) < limit:
                break
            
            page += 1
        else:
            print(f"Error on page {page}: {response.status_code}")
            break

    return sorted(list(all_titles))

# Fetch all style titles
style_titles = get_all_style_titles()

if style_titles:
    print(f"\nTotal styles retrieved: {len(style_titles)}")
else:
    print("Failed to retrieve style titles.")
# Out:
# Total styles retrieved: 9585

# %% [markdown]
# Match the style from the top_styles list to the style terms used by the API

# %%
found_styles_api = check_top_styles(style_titles, top_styles)
# Out:
# The following styles were not found in the df:
# - Academicism
# - Color Field Painting
# - Orientalism
# - Neo-Impressionism
#
# Matches found:
# Impressionism:
#   - Impressionism
# Realism:
#   - Realism
# Romanticism:
#   - neo-romantic
#   - romantic
# Expressionism:
#   - Expressionism
# Post-Impressionism:
#   - Post-Impressionism
# Baroque:
#   - Baroque
# Art Nouveau (Modern):
#   - Modern Art
#   - Modernism
#   - modern
#   - modern art
#   - modernism
#   - modernist
# Surrealism:
#   - Surrealism
#   - surrealism
# Symbolism:
#   - Symbolism
#   - symbolism
# Abstract Expressionism:
#   - Abstract Expressionism
# Neoclassicism:
#   - Neoclassicism
# Rococo:
#   - Rococo
# Cubism:
#   - Cubism
# Northern Renaissance:
#   - northern renaissance
# Pop Art:
#   - Pop Art
#   - Pop art
# Mannerism (Late Renaissance):
#   - Mannerism
#   - late renaissance
#   - mannerism
# Minimalism:
#   - Minimalism
#   - minimalism
# Conceptual Art:
#   - Conceptual Art
# Abstract Art:
#   - Abstract
#   - Abstract Expressionism
#   - Abstraction
#   - abstract
#   - abstract figures
#   - abstract forms
#   - abstract imagist
#   - abstract impressionist
#   - abstract motifs
#   - abstract objects
#   - abstract patterns
#   - abstract shapes
#   - abstraction
#   - eccentric abstraction
#   - lyrical abstraction
# Art Informel:
#   - Art Informel
# Early Renaissance:
#   - early renaissance
# Ukiyo-e:
#   - ukiyo-e
# Neo-Expressionism:
#   - Neo-Expressionism
# High Renaissance:
#   - high renaissance
# Lyrical Abstraction:
#   - lyrical abstraction
# Fauvism:
#   - Fauvism
# Contemporary:
#   - contemporary
# Op Art:
#   - Op Art
# Art-Deco:
#   - Art Deco
#
# Found 29 out of 33 top styles.

# %% [markdown]
# Now I'm matching 29 our of 33. I'll create a list to search the API since we're getting more matches that way. Then
# I can examine and filter the results.

# %%
# Convert found styles to style_search_terms list
style_search_terms = []
for matches in found_styles_api.values():
    style_search_terms.extend(matches)

# Remove duplicates while preserving order
style_search_terms = list(dict.fromkeys(style_search_terms))

print("Style search terms:")
for term in style_search_terms:
    print(f"- {term}")
print(f"\nTotal unique search terms: {len(style_search_terms)}")
# Out:
# Style search terms:
# - Impressionism
# - Realism
# - neo-romantic
# - romantic
# - Expressionism
# - Post-Impressionism
# - Baroque
# - Modern Art
# - Modernism
# - modern
# - modern art
# - modernism
# - modernist
# - Surrealism
# - surrealism
# - Symbolism
# - symbolism
# - Abstract Expressionism
# - Neoclassicism
# - Rococo
# - Cubism
# - northern renaissance
# - Pop Art
# - Pop art
# - Mannerism
# - late renaissance
# - mannerism
# - Minimalism
# - minimalism
# - Conceptual Art
# - Abstract
# - Abstraction
# - abstract
# - abstract figures
# - abstract forms
# - abstract imagist
# - abstract impressionist
# - abstract motifs
# - abstract objects
# - abstract patterns
# - abstract shapes
# - abstraction
# - eccentric abstraction
# - lyrical abstraction
# - Art Informel
# - early renaissance
# - ukiyo-e
# - Neo-Expressionism
# - high renaissance
# - Fauvism
# - contemporary
# - Op Art
# - Art Deco
#
# Total unique search terms: 53

# %% [markdown]
# Test our search terms by getting the first entry from each style

# %%
BASE_URL = "https://api.artic.edu/api/v1"

def get_artwork_by_style(style_term, limit=1):
    endpoint = f"{BASE_URL}/artworks/search"
    params = {
        "q": style_term,
        "fields": "id,title,style_title,image_id,artwork_type_title",
        "limit": limit
    }
    response = requests.get(endpoint, params=params)
    if response.status_code == 200:
        data = response.json()
        return data.get('data', [])
    else:
        print(f"Error fetching data for {style_term}: {response.status_code}")
        return []

def create_test_dataframe(style_search_terms):
    all_artworks = []
    for term in style_search_terms:
        artworks = get_artwork_by_style(term)
        if artworks:
            artwork = artworks[0]
            artwork['search_term'] = term
            all_artworks.append(artwork)
    
    df = pd.DataFrame(all_artworks)
    if '_score' in df.columns:
        df = df.drop('_score', axis=1)
    return df

# Assuming style_search_terms is already defined
api_test_df = create_test_dataframe(style_search_terms)

print(f"Number of entries in test_df: {len(test_df)}")
# Out:
# Number of entries in test_df: 53

# %%
print(api_test_df.info())
api_test_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artwork_type_title  53 non-null     object
#  1   style_title         35 non-null     object
#  2   id                  53 non-null     int64
#  3   image_id            53 non-null     object
#  4   title               53 non-null     object
#  5   search_term         53 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.6+ KB

# %% [markdown]
# Notice mixed media types were pulled. Searching with the API for just paintings along with the style_terms was causing errors,
# so I decided to pull all and will filter the dataframe afterwards. Also filling the missing 'style_title' values with the 'search_term'.
#
# Now I search for every piece of artwork matching our style terms, adhering to the API's rate limiting.

# %%
BASE_URL = "https://api.artic.edu/api/v1"
RATE_LIMIT = 60  # requests per minute
MAX_RECORDS = 10000  # maximum records we can fetch for a single search query
CHECKPOINT_FILE = 'search_checkpoint.json'

def load_checkpoint():
    try:
        with open(CHECKPOINT_FILE, 'r') as f:
            return json.load(f)
    except FileNotFoundError:
        return {}

def save_checkpoint(checkpoint):
    with open(CHECKPOINT_FILE, 'w') as f:
        json.dump(checkpoint, f)

def get_artworks_by_style(style_term, limit=100, start_page=1):
    all_artworks = []
    page = start_page
    total_pages = None

    while (total_pages is None or page <= total_pages) and len(all_artworks) < MAX_RECORDS:
        try:
            endpoint = f"{BASE_URL}/artworks/search"
            params = {
                "q": style_term,
                "fields": "id,title,style_title,image_id,artwork_type_title",
                "limit": limit,
                "page": page
            }
            response = requests.get(endpoint, params=params)
            response.raise_for_status()
            
            data = response.json()
            artworks = data.get('data', [])
            all_artworks.extend(artworks)
            
            if total_pages is None:
                total_pages = data.get('pagination', {}).get('total_pages', 1)
                print(f"Total pages for {style_term}: {total_pages}")
            
            print(f"Fetched page {page} of {total_pages} for {style_term}")
            page += 1
            
            # Throttle to respect rate limit
            time.sleep(60 / RATE_LIMIT)
        
        except RequestException as e:
            print(f"Error fetching data for {style_term} on page {page}: {e}")
            break  
        
        if len(all_artworks) >= MAX_RECORDS:
            print(f"Reached {MAX_RECORDS} record limit for {style_term}")
            break
    
    return all_artworks, page

def create_full_dataframe(style_search_terms):
    all_artworks = []
    checkpoint = load_checkpoint()

    for term in style_search_terms:
        start_page = checkpoint.get(term, {}).get('next_page', 1)
        total_retrieved = checkpoint.get(term, {}).get('total_retrieved', 0)
        
        print(f"Fetching artworks for {term} starting from page {start_page}")
        artworks, next_page = get_artworks_by_style(term, start_page=start_page)
        
        for artwork in artworks:
            artwork['search_term'] = term
        all_artworks.extend(artworks)
        
        total_retrieved += len(artworks)
        checkpoint[term] = {'next_page': next_page, 'total_retrieved': total_retrieved}
        save_checkpoint(checkpoint)
        
        print(f"Total artworks retrieved for {term}: {total_retrieved}")
        
        if total_retrieved >= MAX_RECORDS:
            print(f"Reached {MAX_RECORDS} record limit for {term}. You can resume later.")
    
    df = pd.DataFrame(all_artworks)
    if '_score' in df.columns:
        df = df.drop('_score', axis=1)
    return df

# Usage
full_df = create_full_dataframe(style_search_terms)

print(f"Total number of artworks retrieved: {len(full_df)}")
# Out:
# Fetching artworks for Impressionism starting from page 5
# Total pages for Impressionism: 4
# Fetched page 5 of 4 for Impressionism
# Total artworks retrieved for Impressionism: 316
# Fetching artworks for Realism starting from page 1
# Total pages for Realism: 3
# Fetched page 1 of 3 for Realism
# Fetched page 2 of 3 for Realism
# Fetched page 3 of 3 for Realism
# Total artworks retrieved for Realism: 275
# Fetching artworks for neo-romantic starting from page 1
# Total pages for neo-romantic: 24
# Fetched page 1 of 24 for neo-romantic
# Fetched page 2 of 24 for neo-romantic
# Fetched page 3 of 24 for neo-romantic
# Fetched page 4 of 24 for neo-romantic
# Fetched page 5 of 24 for neo-romantic
# Fetched page 6 of 24 for neo-romantic
# Fetched page 7 of 24 for neo-romantic
# Fetched page 8 of 24 for neo-romantic
# Fetched page 9 of 24 for neo-romantic
# Fetched page 10 of 24 for neo-romantic
# Error fetching data for neo-romantic on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=neo-romantic&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for neo-romantic: 1000
# Fetching artworks for romantic starting from page 1
# Total pages for romantic: 24
# Fetched page 1 of 24 for romantic
# Fetched page 2 of 24 for romantic
# Fetched page 3 of 24 for romantic
# Fetched page 4 of 24 for romantic
# Fetched page 5 of 24 for romantic
# Fetched page 6 of 24 for romantic
# Fetched page 7 of 24 for romantic
# Fetched page 8 of 24 for romantic
# Fetched page 9 of 24 for romantic
# Fetched page 10 of 24 for romantic
# Error fetching data for romantic on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=romantic&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for romantic: 1000
# Fetching artworks for Expressionism starting from page 1
# Total pages for Expressionism: 1
# Fetched page 1 of 1 for Expressionism
# Total artworks retrieved for Expressionism: 12
# Fetching artworks for Post-Impressionism starting from page 1
# Total pages for Post-Impressionism: 5
# Fetched page 1 of 5 for Post-Impressionism
# Fetched page 2 of 5 for Post-Impressionism
# Fetched page 3 of 5 for Post-Impressionism
# Fetched page 4 of 5 for Post-Impressionism
# Fetched page 5 of 5 for Post-Impressionism
# Total artworks retrieved for Post-Impressionism: 455
# Fetching artworks for Baroque starting from page 1
# Total pages for Baroque: 3
# Fetched page 1 of 3 for Baroque
# Fetched page 2 of 3 for Baroque
# Fetched page 3 of 3 for Baroque
# Total artworks retrieved for Baroque: 213
# Fetching artworks for Modern Art starting from page 1
# Total pages for Modern Art: 433
# Fetched page 1 of 433 for Modern Art
# Fetched page 2 of 433 for Modern Art
# Fetched page 3 of 433 for Modern Art
# Fetched page 4 of 433 for Modern Art
# Fetched page 5 of 433 for Modern Art
# Fetched page 6 of 433 for Modern Art
# Fetched page 7 of 433 for Modern Art
# Fetched page 8 of 433 for Modern Art
# Fetched page 9 of 433 for Modern Art
# Fetched page 10 of 433 for Modern Art
# Error fetching data for Modern Art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q
fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Mannerism: 1000
# Fetching artworks for late renaissance starting from page 1
# Total pages for late renaissance: 29
# Fetched page 1 of 29 for late renaissance
# Fetched page 2 of 29 for late renaissance
# Fetched page 3 of 29 for late renaissance
# Fetched page 4 of 29 for late renaissance
# Fetched page 5 of 29 for late renaissance
# Fetched page 6 of 29 for late renaissance
# Fetched page 7 of 29 for late renaissance
# Fetched page 8 of 29 for late renaissance
# Fetched page 9 of 29 for late renaissance
# Fetched page 10 of 29 for late renaissance
# Error fetching data for late renaissance on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=late+renaissance&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for late renaissance: 1000
# Fetching artworks for mannerism starting from page 1
# Total pages for mannerism: 41
# Fetched page 1 of 41 for mannerism
# Fetched page 2 of 41 for mannerism
# Fetched page 3 of 41 for mannerism
# Fetched page 4 of 41 for mannerism
# Fetched page 5 of 41 for mannerism
# Fetched page 6 of 41 for mannerism
# Fetched page 7 of 41 for mannerism
# Fetched page 8 of 41 for mannerism
# Fetched page 9 of 41 for mannerism
# Fetched page 10 of 41 for mannerism
# Error fetching data for mannerism on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=mannerism&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for mannerism: 1000
# Fetching artworks for Minimalism starting from page 1
# Total pages for Minimalism: 1
# Fetched page 1 of 1 for Minimalism
# Total artworks retrieved for Minimalism: 17
# Fetching artworks for minimalism starting from page 1
# Total pages for minimalism: 1
# Fetched page 1 of 1 for minimalism
# Total artworks retrieved for minimalism: 17
# Fetching artworks for Conceptual Art starting from page 1
# Total pages for Conceptual Art: 423
# Fetched page 1 of 423 for Conceptual Art
# Fetched page 2 of 423 for Conceptual Art
# Fetched page 3 of 423 for Conceptual Art
# Fetched page 4 of 423 for Conceptual Art
# Fetched page 5 of 423 for Conceptual Art
# Fetched page 6 of 423 for Conceptual Art
# Fetched page 7 of 423 for Conceptual Art
# Fetched page 8 of 423 for Conceptual Art
# Fetched page 9 of 423 for Conceptual Art
# Fetched page 10 of 423 for Conceptual Art
# Error fetching data for Conceptual Art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Conceptual+Art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Conceptual Art: 1000
# Fetching artworks for Abstract starting from page 1
# Total pages for Abstract: 7
# Fetched page 1 of 7 for Abstract
# Fetched page 2 of 7 for Abstract
# Fetched page 3 of 7 for Abstract
# Fetched page 4 of 7 for Abstract
# Fetched page 5 of 7 for Abstract
# Fetched page 6 of 7 for Abstract
# Fetched page 7 of 7 for Abstract
# Total artworks retrieved for Abstract: 677
# Fetching artworks for Abstraction starting from page 1
# Total pages for Abstraction: 7
# Fetched page 1 of 7 for Abstraction
# Fetched page 2 of 7 for Abstraction
# Fetched page 3 of 7 for Abstraction
# Fetched page 4 of 7 for Abstraction
# Fetched page 5 of 7 for Abstraction
# Fetched page 6 of 7 for Abstraction
# Fetched page 7 of 7 for Abstraction
# Total artworks retrieved for Abstraction: 677
# Fetching artworks for abstract starting from page 1
# Total pages for abstract: 7
# Fetched page 1 of 7 for abstract
# Fetched page 2 of 7 for abstract
# Fetched page 3 of 7 for abstract
# Fetched page 4 of 7 for abstract
# Fetched page 5 of 7 for abstract
# Fetched page 6 of 7 for abstract
# Fetched page 7 of 7 for abstract
# Total artworks retrieved for abstract: 677
# Fetching artworks for abstract figures starting from page 1
# Total pages for abstract figures: 33
# Fetched page 1 of 33 for abstract figures
# Fetched page 2 of 33 for abstract figures
# Fetched page 3 of 33 for abstract figures
# Fetched page 4 of 33 for abstract figures
# Fetched page 5 of 33 for abstract figures
# Fetched page 6 of 33 for abstract figures
# Fetched page 7 of 33 for abstract figures
# Fetched page 8 of 33 for abstract figures
# Fetched page 9 of 33 for abstract figures
# Fetched page 10 of 33 for abstract figures
# Error fetching data for abstract figures on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=abstract+figures&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for abstract figures: 1000
# Fetching artworks for abstract forms starting from page 1
# Total pages for abstract forms: 291
# Fetched page 1 of 291 for abstract forms
# Fetched page 2 of 291 for abstract forms
# Fetched page 3 of 291 for abstract forms
# Fetched page 4 of 291 for abstract forms
# Fetched page 5 of 291 for abstract forms
# Fetched page 6 of 291 for abstract forms
# Fetched page 7 of 291 for abstract forms
# Fetched page 8 of 291 for abstract forms
# Fetched page 9 of 291 for abstract forms
# Fetched page 10 of 291 for abstract forms
# Error fetching data for abstract forms on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=abstract+forms&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for abstract forms: 1000
# Fetching artworks for abstract imagist starting from page 1
# Total pages for abstract imagist: 7
# Fetched page 1 of 7 for abstract imagist
# Fetched page 2 of 7 for abstract imagist
# Fetched page 3 of 7 for abstract imagist
# Fetched page 4 of 7 for abstract imagist
# Fetched page 5 of 7 for abstract imagist
# Fetched page 6 of 7 for abstract imagist
# Fetched page 7 of 7 for abstract imagist
# Total artworks retrieved for abstract imagist: 688
# Fetching artworks for abstract impressionist starting from page 1
# Total pages for abstract impressionist: 7
# Fetched page 1 of 7 for abstract impressionist
# Fetched page 2 of 7 for abstract impressionist
# Fetched page 3 of 7 for abstract impressionist
# Fetched page 4 of 7 for abstract impressionist
# Fetched page 5 of 7 for abstract impressionist
# Fetched page 6 of 7 for abstract impressionist
# Fetched page 7 of 7 for abstract impressionist
# Total artworks retrieved for abstract impressionist: 664
# Fetching artworks for abstract motifs starting from page 1
# Total pages for abstract motifs: 14
# Fetched page 1 of 14 for abstract motifs
# Fetched page 2 of 14 for abstract motifs
# Fetched page 3 of 14 for abstract motifs
# Fetched page 4 of 14 for abstract motifs
# Fetched page 5 of 14 for abstract motifs
# Fetched page 6 of 14 for abstract motifs
# Fetched page 7 of 14 for abstract motifs
# Fetched page 8 of 14 for abstract motifs
# Fetched page 9 of 14 for abstract motifs
# Fetched page 10 of 14 for abstract motifs
# Error fetching data for abstract motifs on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=abstract+motifs&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for abstract motifs: 1000
# Fetching artworks for abstract objects starting from page 1
# Total pages for abstract objects: 24
# Fetched page 1 of 24 for abstract objects
# Fetched page 2 of 24 for abstract objects
# Fetched page 3 of 24 for abstract objects
# Fetched page 4 of 24 for abstract objects
# Fetched page 5 of 24 for abstract objects
# Fetched page 6 of 24 for abstract objects
# Fetched page 7 of 24 for abstract objects
# Fetched page 8 of 24 for abstract objects
# Fetched page 9 of 24 for abstract objects
# Fetched page 10 of 24 for abstract objects
# Error fetching data for abstract objects on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=abstract+objects&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for abstract objects: 1000
# Fetching artworks for abstract patterns starting from page 1
# Total pages for abstract patterns: 46
# Fetched page 1 of 46 for abstract patterns
# Fetched page 2 of 46 for abstract patterns
# Fetched page 3 of 46 for abstract patterns
# Fetched page 4 of 46 for abstract patterns
# Fetched page 5 of 46 for abstract patterns
# Fetched page 6 of 46 for abstract patterns
# Fetched page 7 of 46 for abstract patterns
# Fetched page 8 of 46 for abstract patterns
# Fetched page 9 of 46 for abstract patterns
# Fetched page 10 of 46 for abstract patterns
# Error fetching data for abstract patterns on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=abstract+patterns&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for abstract patterns: 1000
# Fetching artworks for abstract shapes starting from page 1
# Total pages for abstract shapes: 15
# Fetched page 1 of 15 for abstract shapes
# Fetched page 2 of 15 for abstract shapes
# Fetched page 3 of 15 for abstract shapes
# Fetched page 4 of 15 for abstract shapes
# Fetched page 5 of 15 for abstract shapes
# Fetched page 6 of 15 for abstract shapes
# Fetched page 7 of 15 for abstract shapes
# Fetched page 8 of 15 for abstract shapes
# Fetched page 9 of 15 for abstract shapes
# Fetched page 10 of 15 for abstract shapes
# Error fetching data for abstract shapes on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=abstract+shapes&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for abstract shapes: 1000
# Fetching artworks for abstraction starting from page 1
# Total pages for abstraction: 7
# Fetched page 1 of 7 for abstraction
# Fetched page 2 of 7 for abstraction
# Fetched page 3 of 7 for abstraction
# Fetched page 4 of 7 for abstraction
# Fetched page 5 of 7 for abstraction
# Fetched page 6 of 7 for abstraction
# Fetched page 7 of 7 for abstraction
# Total artworks retrieved for abstraction: 677
# Fetching artworks for eccentric abstraction starting from page 1
# Total pages for eccentric abstraction: 8
# Fetched page 1 of 8 for eccentric abstraction
# Fetched page 2 of 8 for eccentric abstraction
# Fetched page 3 of 8 for eccentric abstraction
# Fetched page 4 of 8 for eccentric abstraction
# Fetched page 5 of 8 for eccentric abstraction
# Fetched page 6 of 8 for eccentric abstraction
# Fetched page 7 of 8 for eccentric abstraction
# Fetched page 8 of 8 for eccentric abstraction
# Total artworks retrieved for eccentric abstraction: 740
# Fetching artworks for lyrical abstraction starting from page 1
# Total pages for lyrical abstraction: 7
# Fetched page 1 of 7 for lyrical abstraction
# Fetched page 2 of 7 for lyrical abstraction
# Fetched page 3 of 7 for lyrical abstraction
# Fetched page 4 of 7 for lyrical abstraction
# Fetched page 5 of 7 for lyrical abstraction
# Fetched page 6 of 7 for lyrical abstraction
# Fetched page 7 of 7 for lyrical abstraction
# Total artworks retrieved for lyrical abstraction: 697
# Fetching artworks for Art Informel starting from page 1
# Total pages for Art Informel: 413
# Fetched page 1 of 413 for Art Informel
# Fetched page 2 of 413 for Art Informel
# Fetched page 3 of 413 for Art Informel
# Fetched page 4 of 413 for Art Informel
# Fetched page 5 of 413 for Art Informel
# Fetched page 6 of 413 for Art Informel
# Fetched page 7 of 413 for Art Informel
# Fetched page 8 of 413 for Art Informel
# Fetched page 9 of 413 for Art Informel
# Fetched page 10 of 413 for Art Informel
# Error fetching data for Art Informel on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Art+Informel&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Art Informel: 1000
# Fetching artworks for early renaissance starting from page 1
# Total pages for early renaissance: 29
# Fetched page 1 of 29 for early renaissance
# Fetched page 2 of 29 for early renaissance
# Fetched page 3 of 29 for early renaissance
# Fetched page 4 of 29 for early renaissance
# Fetched page 5 of 29 for early renaissance
# Fetched page 6 of 29 for early renaissance
# Fetched page 7 of 29 for early renaissance
# Fetched page 8 of 29 for early renaissance
# Fetched page 9 of 29 for early renaissance
# Fetched page 10 of 29 for early renaissance
# Error fetching data for early renaissance on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=early+renaissance&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for early renaissance: 1000
# Fetching artworks for ukiyo-e starting from page 1
# Total pages for ukiyo-e: 43
# Fetched page 1 of 43 for ukiyo-e
# Fetched page 2 of 43 for ukiyo-e
# Fetched page 3 of 43 for ukiyo-e
# Fetched page 4 of 43 for ukiyo-e
# Fetched page 5 of 43 for ukiyo-e
# Fetched page 6 of 43 for ukiyo-e
# Fetched page 7 of 43 for ukiyo-e
# Fetched page 8 of 43 for ukiyo-e
# Fetched page 9 of 43 for ukiyo-e
# Fetched page 10 of 43 for ukiyo-e
# Error fetching data for ukiyo-e on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=ukiyo-e&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for ukiyo-e: 1000
# Fetching artworks for Neo-Expressionism starting from page 1
# Total pages for Neo-Expressionism: 1
# Fetched page 1 of 1 for Neo-Expressionism
# Total artworks retrieved for Neo-Expressionism: 20
# Fetching artworks for high renaissance starting from page 1
# Total pages for high renaissance: 5
# Fetched page 1 of 5 for high renaissance
# Fetched page 2 of 5 for high renaissance
# Fetched page 3 of 5 for high renaissance
# Fetched page 4 of 5 for high renaissance
# Fetched page 5 of 5 for high renaissance
# Total artworks retrieved for high renaissance: 448
# Fetching artworks for Fauvism starting from page 1
# Total pages for Fauvism: 1
# Fetched page 1 of 1 for Fauvism
# Total artworks retrieved for Fauvism: 24
# Fetching artworks for contemporary starting from page 1
# Total pages for contemporary: 33
# Fetched page 1 of 33 for contemporary
# Fetched page 2 of 33 for contemporary
# Fetched page 3 of 33 for contemporary
# Fetched page 4 of 33 for contemporary
# Fetched page 5 of 33 for contemporary
# Fetched page 6 of 33 for contemporary
# Fetched page 7 of 33 for contemporary
# Fetched page 8 of 33 for contemporary
# Fetched page 9 of 33 for contemporary
# Fetched page 10 of 33 for contemporary
# Error fetching data for contemporary on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=contemporary&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for contemporary: 1000
# Fetching artworks for Op Art starting from page 1
# Total pages for Op Art: 419
# Fetched page 1 of 419 for Op Art
# Fetched page 2 of 419 for Op Art
# Fetched page 3 of 419 for Op Art
# Fetched page 4 of 419 for Op Art
# Fetched page 5 of 419 for Op Art
# Fetched page 6 of 419 for Op Art
# Fetched page 7 of 419 for Op Art
# Fetched page 8 of 419 for Op Art
# Fetched page 9 of 419 for Op Art
# Fetched page 10 of 419 for Op Art
# Error fetching data for Op Art on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Op+Art&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Op Art: 1000
# Fetching artworks for Art Deco starting from page 1
# Total pages for Art Deco: 416
# Fetched page 1 of 416 for Art Deco
# Fetched page 2 of 416 for Art Deco
# Fetched page 3 of 416 for Art Deco
# Fetched page 4 of 416 for Art Deco
# Fetched page 5 of 416 for Art Deco
# Fetched page 6 of 416 for Art Deco
# Fetched page 7 of 416 for Art Deco
# Fetched page 8 of 416 for Art Deco
# Fetched page 9 of 416 for Art Deco
# Fetched page 10 of 416 for Art Deco
# Error fetching data for Art Deco on page 11: 403 Client Error: Forbidden for url: https://api.artic.edu/api/v1/artworks/search?q=Art+Deco&fields=id%2Ctitle%2Cstyle_title%2Cimage_id%2Cartwork_type_title&limit=100&page=11
# Total artworks retrieved for Art Deco: 1000
# Total number of artworks retrieved: 34632

# %%
full_df.head(10)
# Out:
#   artwork_type_title    style_title      id  \
# 0           Painting    suprematist  207293
# 1           Painting        Realism   27138
# 2           Painting        Realism  121629
# 3          Sculpture        Realism  191185
# 4           Painting        Realism  111377
# 5           Painting        Realism  181777
# 6           Painting  Impressionism    4749
# 7              Print        Realism  192634
# 8           Painting        Realism   81564
# 9              Print        Realism  192586
#
#                                image_id  \
# 0  12baff03-af57-0410-df53-740c56575732
# 1  e1f6ef79-7216-4f19-ac78-a307a2fb4f32
# 2  e6dd6199-c245-d1b4-a997-ce89eafb48ca
# 3  f2f929b9-995a-9ed3-ef39-2fe81b35a64e
# 4  3cea045a-92d6-36cf-1508-2c99ea740218
# 5  6754947f-4ccf-b3ff-41ee-45b738534769
# 6  074c1b1b-fe92-01ce-9e62-cc99369142dd
# 7  c4824acc-1240-8f7b-abf9-f1b32435990c
# 8  8a647e1c-d778-db71-6ba4-6456b800d6b9
# 9  3110a7a4-a6df-dca4-1f42-e3290d07e4af
#
#                                                title search_term
# 0  Painterly Realism of a Football Player—Color M...     Realism
# 1                                 A Friendly Warning     Realism
# 2             Life Study (Study of an Egyptian Girl)     Realism
# 3                                        The Puritan     Realism
# 4                                For Sunday's Dinner     Realism
# 5                                 The Irish Question     Realism
# 6           Mrs. George Swinton (Elizabeth Ebsworth)     Realism
# 7                         Glory to the Soviet Youth!     Realism
# 8                   Husking Bee, Island of Nantucket     Realism
# 9                               Königsberg Is Taken!     Realism

# %%
full_df['artwork_type_title'].value_counts()
# Out:
# artwork_type_title
# Painting                   8844
# Print                      4675
# Vessel                     4187
# Sculpture                  3701
# Photograph                 2722
# Drawing and Watercolor     1719
# Textile                    1672
# Decorative Arts             820
# Costume and Accessories     817
# Ceramics                    793
# Coin                        710
# Religious/Ritual Object     461
# Mixed Media                 453
# Graphic Design              426
# Furniture                   352
# Architectural Drawing       316
# Metalwork                   313
# Glass                       201
# Book                        192
# Mask                        191
# Architectural fragment      156
# Design                      147
# Installation                120
# Film, Video, New Media      119
# Armor                        65
# Coverings and Hangings       64
# Basketry                     63
# Miniature room               61
# Funerary Object              58
# Arms                         58
# Model                        43
# Archives (groupings)         42
# Furnishings                  22
# Miniature Painting           10
# Icon                          5
# Time Based Media              3
# non-art                       2
# Name: count, dtype: int64

# %%
# Now filter for only paintings or prints
filtered_full_df = full_df[(full_df['artwork_type_title'] == 'Painting') | (full_df['artwork_type_title'] == 'Print')]
filtered_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13519 entries, 0 to 34622
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artwork_type_title  13519 non-null  object
#  1   style_title         6397 non-null   object
#  2   id                  13519 non-null  int64
#  3   image_id            13341 non-null  object
#  4   title               13519 non-null  object
#  5   search_term         13519 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 739.3+ KB

# %%
filtered_full_df['artwork_type_title'].value_counts()
# Out:
# artwork_type_title
# Painting    8844
# Print       4675
# Name: count, dtype: int64

# %%
filtered_full_df.isna().sum()
# Out:
# artwork_type_title       0
# style_title           7122
# id                       0
# image_id               178
# title                    0
# search_term              0
# dtype: int64

# %%
filtered_full_df['style_title'] = filtered_full_df['style_title'].fillna(filtered_full_df['search_term'])
filtered_full_df = filtered_full_df.dropna()
# Out:
# C:\Users\16148\AppData\Local\Temp\ipykernel_41040\3016425490.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_full_df['style_title'] = filtered_full_df['style_title'].fillna(filtered_full_df['search_term'])

# %%
filtered_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13341 entries, 0 to 34622
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artwork_type_title  13341 non-null  object
#  1   style_title         13341 non-null  object
#  2   id                  13341 non-null  int64
#  3   image_id            13341 non-null  object
#  4   title               13341 non-null  object
#  5   search_term         13341 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 729.6+ KB

# %% [markdown]
# Download the images we want.

# %%
BASE_URL = "https://www.artic.edu/iiif/2/"
RATE_LIMIT = 60  # requests per minute
IMAGE_QUALITY = "full"
IMAGE_FORMAT = "jpg"
OUTPUT_DIR = 'downloaded_images_aic'
MAX_RETRIES = 2  # Retry up to 2 times if the content is empty or there are errors
RETRY_DELAY = 2  # Delay (in seconds) between retries
REQUEST_DELAY = 1  # Delay (in seconds) between each request

# Set up logging
logging.basicConfig(filename='image_download.log', level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s', datefmt='%d-%b-%y %H:%M:%S')

def download_image(image_id, output_path):
    if not image_id:
        return False, "No image ID provided"
    
    url = urljoin(BASE_URL, f"{image_id}/full/{IMAGE_QUALITY}/0/default.{IMAGE_FORMAT}")
    for attempt in range(MAX_RETRIES + 1):  # Attempt download + retries
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()  # Raises an HTTPError for bad responses
            
            # Log content length and headers
            content_length = len(response.content)
            logging.info(f"Attempt {attempt + 1} - Content length: {content_length}, Headers: {response.headers}")
            
            # Check for non-empty content
            if content_length > 0:
                with open(output_path, 'wb') as f:
                    f.write(response.content)
                
                # Check that the file was written and is not empty
                if os.path.exists(output_path) and os.path.getsize(output_path) > 0:
                    return True, "Success"
                else:
                    logging.warning(f"Downloaded file {output_path} is empty.")
            else:
                logging.warning(f"Attempt {attempt + 1} - Empty content for {image_id}")
        
        except requests.exceptions.HTTPError as e:
            return False, f"HTTP error: {e}"
        except requests.exceptions.ConnectionError as e:
            return False, f"Connection error: {e}"
        except requests.exceptions.Timeout as e:
            return False, f"Timeout error: {e}"
        except requests.exceptions.RequestException as e:
            return False, f"Error downloading: {e}"

        # Wait before retrying if not the last attempt
        if attempt < MAX_RETRIES:
            logging.info(f"Retrying in {RETRY_DELAY} seconds (attempt {attempt + 2}) for {image_id}")
            time.sleep(RETRY_DELAY)

    return False, "Failed after maximum retries"

def download_all_images(df):
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    file_names = []
    total_images = len(df)
    successful_downloads = 0
    failed_downloads = 0
    skipped_downloads = 0
    
    for index, row in df.iterrows():
        image_id = row['image_id']
        if pd.isna(image_id) or not image_id:
            file_names.append(None)
            skipped_downloads += 1
            logging.warning(f"Skipped image at index {index}: No valid image_id")
            continue

        file_name = f"{image_id}.{IMAGE_FORMAT}"
        output_path = os.path.join(OUTPUT_DIR, file_name)

        success, message = download_image(image_id, output_path)
        if success:
            file_names.append(file_name)
            successful_downloads += 1
            logging.info(f"Downloaded: {file_name}")
        else:
            file_names.append(None)
            failed_downloads += 1
            logging.warning(f"Failed to download {image_id}: {message}")

        # Print progress every 100 images
        if (index + 1) % 100 == 0:
            print(f"Progress: {index + 1}/{total_images} images processed")
            print(f"Successful downloads: {successful_downloads}")
            print(f"Failed downloads: {failed_downloads}")
            print(f"Skipped downloads: {skipped_downloads}")
            logging.info(f"Progress: {index + 1}/{total_images} images processed. "
                         f"Successful: {successful_downloads}, Failed: {failed_downloads}, Skipped: {skipped_downloads}")

        # Throttle to respect rate limit and add a 1-second delay between requests
        time.sleep(1)

    return file_names, successful_downloads, failed_downloads, skipped_downloads

# Usage
file_names, successful, failed, skipped = download_all_images(filtered_full_df)
filtered_full_df['file_name'] = file_names

print(f"Image download complete. Total successful downloads: {successful}, "
      f"Total failed: {failed}, Total skipped: {skipped}")
logging.info(f"Process completed. Successful downloads: {successful}, "
             f"Failed downloads: {failed}, Skipped downloads: {skipped}")
# Out:
# Progress: 100/13341 images processed
# Successful downloads: 81
# Failed downloads: 0
# Skipped downloads: 0
# Progress: 200/13341 images processed
# Successful downloads: 167
# Failed downloads: 3
# Skipped downloads: 0
# Progress: 800/13341 images processed
# Successful downloads: 260
# Failed downloads: 5
# Skipped downloads: 0
# Progress: 1600/13341 images processed
# Successful downloads: 342
# Failed downloads: 7
# Skipped downloads: 0
# Progress: 2300/13341 images processed
# Successful downloads: 458
# Failed downloads: 7
# Skipped downloads: 0
# Progress: 2400/13341 images processed
# Successful downloads: 535
# Failed downloads: 7
# Skipped downloads: 0
# Progress: 2600/13341 images processed
# Successful downloads: 692
# Failed downloads: 7
# Skipped downloads: 0
# Progress: 2800/13341 images processed
# Successful downloads: 802
# Failed downloads: 8
# Skipped downloads: 0
# Progress: 3000/13341 images processed
# Successful downloads: 908
# Failed downloads: 10
# Skipped downloads: 0
# Progress: 3100/13341 images processed
# Successful downloads: 981
# Failed downloads: 12
# Skipped downloads: 0
# Progress: 3300/13341 images processed
# Successful downloads: 1117
# Failed downloads: 13
# Skipped downloads: 0
# Progress: 3400/13341 images processed
# Successful downloads: 1178
# Failed downloads: 14
# Skipped downloads: 0
# Progress: 3500/13341 images processed
# Successful downloads: 1251
# Failed downloads: 14
# Skipped downloads: 0
# Progress: 3600/13341 images processed
# Successful downloads: 1305
# Failed downloads: 16
# Skipped downloads: 0
# Progress: 3800/13341 images processed
# Successful downloads: 1441
# Failed downloads: 16
# Skipped downloads: 0
# Progress: 3900/13341 images processed
# Successful downloads: 1506
# Failed downloads: 16
# Skipped downloads: 0
# Progress: 4100/13341 images processed
# Successful downloads: 1662
# Failed downloads: 16
# Skipped downloads: 0
# Progress: 4300/13341 images processed
# Successful downloads: 1811
# Failed downloads: 18
# Skipped downloads: 0
# Progress: 4400/13341 images processed
# Successful downloads: 1870
# Failed downloads: 19
# Skipped downloads: 0
# Progress: 4600/13341 images processed
# Successful downloads: 1988
# 0  Painterly Realism of a Football Player—Color M...     Realism
# 1                                 A Friendly Warning     Realism
# 2             Life Study (Study of an Egyptian Girl)     Realism
# 4                                For Sunday's Dinner     Realism
# 5                                 The Irish Question     Realism
#
#                                   file_name
# 0  12baff03-af57-0410-df53-740c56575732.jpg
# 1  e1f6ef79-7216-4f19-ac78-a307a2fb4f32.jpg
# 2  e6dd6199-c245-d1b4-a997-ce89eafb48ca.jpg
# 4  3cea045a-92d6-36cf-1508-2c99ea740218.jpg
# 5  6754947f-4ccf-b3ff-41ee-45b738534769.jpg

# %% [markdown]
# Check dataframe against actual files in the directory

# %%
# Get path to check files
image_dir = 'downloaded_images_aic'

# First remove rows where file_name is None
filtered_full_df = filtered_full_df.dropna(subset=['file_name'])

# Now create mask of existing files
exists_mask = filtered_full_df['file_name'].apply(lambda x: os.path.exists(os.path.join(image_dir, x)))

# Filter DataFrame to keep only rows where files exist
filtered_full_df = filtered_full_df[exists_mask]

# %%
filtered_full_df['artwork_type_title'].value_counts()
# Out:
# artwork_type_title
# Painting    8626
# Print       4570
# Name: count, dtype: int64

# %%
# Get count of duplicates
duplicate_count = filtered_full_df['file_name'].duplicated().sum()

if duplicate_count > 0:
    # Show the duplicate entries
    duplicates = filtered_full_df[filtered_full_df['file_name'].duplicated(keep=False)]
    print(f"Found {duplicate_count} duplicate entries")
else:
    print("No duplicate filenames found")
# Out:
# Found 9074 duplicate entries

# %% [markdown]
# Whoops, probably should have checked for duplicates before downloading.

# %%
filtered_full_df = filtered_full_df.drop_duplicates(subset=['file_name'], keep='first')

# %%
filtered_full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4122 entries, 0 to 33435
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artwork_type_title  4122 non-null   object
#  1   style_title         4122 non-null   object
#  2   id                  4122 non-null   int64
#  3   image_id            4122 non-null   object
#  4   title               4122 non-null   object
#  5   search_term         4122 non-null   object
#  6   file_name           4122 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 257.6+ KB

# %%
filtered_full_df['style_title'].value_counts()
# Out:
# style_title
# Japanese (culture or style)    682
# Pop Art                        472
# Modern Art                     398
# Mannerism                      314
# Cubism                         275
#                               ...
# 13th century                     1
# american colonial                1
# de Stijl                         1
# lakota                           1
# suprematist                      1
# Name: count, Length: 86, dtype: int64

# %%
filtered_full_df['search_term'].value_counts()
# Out:
# search_term
# Modern Art                617
# ukiyo-e                   536
# Pop Art                   476
# Mannerism                 382
# Post-Impressionism        304
# Cubism                    260
# Realism                   195
# early renaissance         123
# neo-romantic              122
# late renaissance          118
# Baroque                   106
# abstract figures           98
# northern renaissance       88
# Abstract Expressionism     83
# Art Informel               59
# Surrealism                 56
# Conceptual Art             54
# Modernism                  52
# Rococo                     45
# abstract patterns          44
# high renaissance           43
# mannerism                  42
# Symbolism                  35
# abstract objects           33
# Fauvism                    22
# abstract motifs            22
# contemporary               19
# abstract shapes            18
# abstract imagist           15
# abstract forms             11
# lyrical abstraction        11
# Neoclassicism               7
# Abstract                    6
# modernist                   4
# Expressionism               4
# romantic                    4
# Op Art                      3
# eccentric abstraction       2
# symbolism                   2
# Minimalism                  1
# Name: count, dtype: int64

# %%
filtered_full_df.to_csv("aic_images.csv", index=False)
